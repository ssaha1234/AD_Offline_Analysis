# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np
import os
import tensorflow as tf
from tensorflow.keras.models import Model
from tensorflow.keras import layers, regularizers
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau
from sklearn.model_selection import train_test_split
from sklearn.metrics import roc_curve, auc
import h5py

def distance_correlation_tf(x, y, eps=1e-8):
    x = tf.reshape(x, [-1, 1])
    y = tf.reshape(y, [-1, 1])
    
    # Pairwise distances
    a = tf.norm(x[:, None, :] - x[None, :, :], axis=-1)
    b = tf.norm(y[:, None, :] - y[None, :, :], axis=-1)
    
    # Double centering
    A = a - tf.reduce_mean(a, axis=0, keepdims=True) \
           - tf.reduce_mean(a, axis=1, keepdims=True) \
           + tf.reduce_mean(a)
    B = b - tf.reduce_mean(b, axis=0, keepdims=True) \
           - tf.reduce_mean(b, axis=1, keepdims=True) \
           + tf.reduce_mean(b)
    
    #eps for avoinding NaN situation
    dcov = tf.sqrt(tf.maximum(tf.reduce_mean(A*B), eps))
    dvar_x = tf.sqrt(tf.maximum(tf.reduce_mean(A*A), eps))
    dvar_y = tf.sqrt(tf.maximum(tf.reduce_mean(B*B), eps))
    
    return dcov / (tf.sqrt(dvar_x*dvar_y) + eps)

def disco_loss(y_true, y_pred, hlt_batch, lambda_disco=10.0):
    """
    Compute per-batch loss: recon MSE + lambda * DisCo penalty
    Returns recon_loss, disco_penalty, total_loss
    """
    # Reconstruction MSE per sample
    recon_per_sample = tf.reduce_mean(tf.square(y_true - y_pred), axis=-1)
    tf.print("Per-sample MSE shape:", tf.shape(recon_per_sample), "values:", recon_per_sample)

    #Batch average
    recon_loss = tf.reduce_mean(recon_per_sample)
    tf.print("Final loss shape:", tf.shape(recon_loss), "value:", recon_loss)

    # Offline anomaly score (same as recon here)
    offline_scores = recon_per_sample
    
    # DisCo penalty
    disco_penalty = distance_correlation_tf(offline_scores, hlt_batch)
    
    # Total loss, add HLT AD score (MSE)
    total_loss = recon_loss + lambda_disco * disco_penalty
    
    return recon_loss, disco_penalty, total_loss

# %%
file_path = "/eos/user/s/ssaha/SWAN_projects/AD_Trigger_1/ntuples/lam_output/lam_test/EB_482596.h5"

with h5py.File(file_path, "r") as f:
    datasets = {k: np.array(f[k]) for k in f}
    datasets["Offline_data"] = datasets["Offline_data"].reshape(-1, 45)
print("Offline_data shape after reshape:", datasets["Offline_data"].shape)
print("Keys in file:", list(datasets.keys()))
print("Offline_data shape:", datasets["Offline_data"].shape)

output_file = '/eos/user/s/ssaha/SWAN_projects/AD_Trigger_1/output_files_DisCo/ad_scores_noDisCo.h5'
with h5py.File(output_file, 'r') as f:
    group = f['EB_test']
    HLT_AD_scores = group['HLT_AD_scores'][:].astype(np.float32)
    #Offline_AD_scores = group['Offline_AD_scores'][:].astype(np.float32)

print('HLT_AD scores',HLT_AD_scores, HLT_AD_scores.shape)
# Out:
# Offline_data shape after reshape: (1048336, 45)
# Keys in file: ['HLT_data', 'L1_data', 'Offline_data', 'event_numbers', 'passHLT', 'passL1', 'pileups', 'run_numbers', 'topo2A_AD_scores', 'weights']
# Offline_data shape: (1048336, 45)
# HLT_AD scores [  0.          0.          0.        ...   2.109743    3.8268185
#  515.9285   ] (1048336,)

# %%
# Create a large Autoencoder (encoder + decoder + AE model)
# ---------------------------------------------------------
def create_large_AE(input_dim, h_dim_1, h_dim_2, h_dim_3, h_dim_4, latent_dim, 
                    l2_reg=0.01, dropout_rate=0.0):
    
    # ---------------- Encoder ----------------
    encoder_inputs = layers.Input(shape=(input_dim,))
    x = layers.Dense(h_dim_1, kernel_regularizer=regularizers.l2(l2_reg))(encoder_inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(h_dim_2, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(h_dim_3, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(h_dim_4, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    z = layers.Dense(latent_dim, kernel_regularizer=regularizers.l2(l2_reg))(x)
    z = layers.BatchNormalization()(z)
    z = layers.Activation('relu')(z)

    encoder = Model(inputs=encoder_inputs, outputs=z, name="encoder")

    # ---------------- Decoder ----------------
    decoder_inputs = layers.Input(shape=(latent_dim,))
    x = layers.Dense(h_dim_4, kernel_regularizer=regularizers.l2(l2_reg))(decoder_inputs)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(h_dim_3, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(h_dim_2, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    x = layers.Dense(h_dim_1, kernel_regularizer=regularizers.l2(l2_reg))(x)
    x = layers.BatchNormalization()(x)
    x = layers.Activation('relu')(x)
    x = layers.Dropout(dropout_rate)(x)

    outputs = layers.Dense(input_dim, kernel_regularizer=regularizers.l2(l2_reg))(x)

    decoder = Model(inputs=decoder_inputs, outputs=outputs, name="decoder")

    # ---------------- Autoencoder ----------------
    ae_outputs = decoder(encoder(encoder_inputs))
    ae = Model(encoder_inputs, outputs=ae_outputs, name="autoencoder")

    return ae, encoder, decoder


INPUT_DIM = 45 #No MET in Offline data yet! 
H_DIM_1 = 100
H_DIM_2 = 100
H_DIM_3 = 64
H_DIM_4 = 32
LATENT_DIM = 4
L2_reg_coupling = 0.01
dropout_p = 0.2

ae, encoder, decoder = create_large_AE(INPUT_DIM, H_DIM_1, H_DIM_2, H_DIM_3, H_DIM_4,
                                       LATENT_DIM, l2_reg=L2_reg_coupling, dropout_rate=dropout_p)

X = datasets["Offline_data"].astype(np.float32)
HLT_scores = HLT_AD_scores 

# Split train/validation
X_train, X_val, hlt_train, hlt_val = train_test_split(
    X, HLT_scores, test_size=0.2, random_state=42
)

optimizer = tf.keras.optimizers.Adam(1e-5)

BATCH_SIZE = 16773
EPOCHS = 1
num_batches = int(np.ceil(len(X_train) / BATCH_SIZE))
print("Total samples in X_train:", len(X_train))
print("Number of batches:", num_batches)

all_total_losses_disco = []

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    
    # Shuffle the training data - check 
    idx = np.arange(len(X_train))
    np.random.shuffle(idx)
    X_train_shuffled = X_train[idx]
    hlt_train_shuffled = hlt_train[idx]
 
    total_recon, total_disco, total_total = 0.0, 0.0, 0.0

    for i in range(num_batches):
        batch_X = X_train_shuffled[i*BATCH_SIZE:(i+1)*BATCH_SIZE]
        batch_hlt = hlt_train_shuffled[i*BATCH_SIZE:(i+1)*BATCH_SIZE]
        
        # Model predictions
        batch_pred = ae(batch_X, training=False)

        # Compute loss with DisCo
        recon_val, disco_val, total_val = disco_loss(
            tf.constant(batch_X, dtype=tf.float32),
            batch_pred,
            tf.constant(batch_hlt, dtype=tf.float32),
            lambda_disco=10.0
        )

        total_recon += np.sum(recon_val.numpy())           # sum over batch
        total_disco += float(disco_val.numpy())            # scalar
        total_total += np.mean(total_val.numpy())          # mean over batch

        # Save per-batch total loss
        all_total_losses_disco.append(np.mean(total_val.numpy()))
print('loss',all_total_losses_disco )

#No back propagation here, use gradient tape for that?
# Keras - back propagation
# Out:
# Total samples in X_train: 838668
# Number of batches: 51
#
# Epoch 1/1
# Per-sample MSE shape: [16773] values: [24.3773708 0 0 ... 288.348358 85.7589 803.734]
# Final loss shape: [] value: 2182.31665
# Per-sample MSE shape: [16773] values: [145.69577 72.9674072 160.783432 ... 52.0121155 71.2855606 53.9495926]
# Final loss shape: [] value: 1292.48633
# Per-sample MSE shape: [16773] values: [436.773651 77.4311523 137.724106 ... 757.737915 211.847092 1176.2782]
# Final loss shape: [] value: 1015.87671
# Per-sample MSE shape: [16773] values: [19.9373856 68.7154846 3.66431928 ... 763.366943 0 31.0943584]
# Final loss shape: [] value: 4365.98096
# Per-sample MSE shape: [16773] values: [433.362152 0 95.693367 ... 549.44342 22.8241653 296.668488]
# Final loss shape: [] value: 11408397
# Per-sample MSE shape: [16773] values: [306.771179 0 136.311295 ... 346.629089 6.1140213 1274.83203]
# Final loss shape: [] value: 47026.0625
# Per-sample MSE shape: [16773] values: [70.8425 298.470215 99.7860641 ... 79.253479 79.3036575 76.5099564]
# Final loss shape: [] value: 3539.63501
# Per-sample MSE shape: [16773] values: [12.4231186 4.46811676 0 ... 371.917419 46.3508568 41.031208]
# Final loss shape: [] value: 80021.9219
# Per-sample MSE shape: [16773] values: [240.347458 91.2525711 180.87471 ... 74.536438 42.4384079 119.97438]
# Final loss shape: [] value: 1076.71472
# Per-sample MSE shape: [16773] values: [212.003189 0 6.27961493 ... 54.1423187 108.031403 0]
# Final loss shape: [] value: 1077.09509
# Per-sample MSE shape: [16773] values: [286.084686 1356.42 42.3176384 ... 932.799377 287.77475 70.9743729]
# Final loss shape: [] value: 3792.83765
# Per-sample MSE shape: [16773] values: [14.6130629 255.366226 386.159332 ... 218.901016 71.2724609 0]
# Final loss shape: [] value: 2969.36743
# Per-sample MSE shape: [16773] values: [4.78829575 12.1816854 308.445648 ... 140.584763 18.8489075 0]
# Final loss shape: [] value: 3771.52661
# Per-sample MSE shape: [16773] values: [75.6398468 5991.53613 213.292511 ... 82.4589844 52.136425 184.236481]
# Final loss shape: [] value: 7649.28857
# Per-sample MSE shape: [16773] values: [118.896683 29.9629593 32.1225052 ... 247.333176 129.236984 151.223]
# Final loss shape: [] value: 5563.51416
# Per-sample MSE shape: [16773] values: [45.9994965 177.528793 18.0322323 ... 140.733871 82.7114563 10.1742306]
# Final loss shape: [] value: 13035.5977
# Per-sample MSE shape: [16773] values: [292.029419 0 0 ... 1066.22 34.0322189 1377.34412]
# Final loss shape: [] value: 2344.52173
# Per-sample MSE shape: [16773] values: [313.576813 419.94046 230.925644 ... 102.970978 114.28096 70.874054]
# Final loss shape: [] value: 590.022766
# Per-sample MSE shape: [16773] values: [0 305.082672 122.533134 ... 117.670326 0 78.471817]
# Final loss shape: [] value: 8808.13184
# Per-sample MSE shape: [16773] values: [88.2687683 9501.0625 0 ... 145.433594 78.8752289 73.8142166]
# Final loss shape: [] value: 7001.60156
# Per-sample MSE shape: [16773] values: [101.783257 579.027832 181.51796 ... 143561.25 27.1272984 119.666168]
# Final loss shape: [] value: 1713.92847
# Per-sample MSE shape: [16773] values: [388.702911 105.797691 23.6187744 ... 344.139 0 103.680107]
# Final loss shape: [] value: 829.904724
# Per-sample MSE shape: [16773] values: [0 144.232407 41.935318 ... 0 326.130219 79.0322189]
# Final loss shape: [] value: 982.29187
# Per-sample MSE shape: [16773] values: [1641.26 25.0158176 80.9982147 ... 408.672729 81.9291687 79.1599503]
# Final loss shape: [] value: 9188.47852
# Per-sample MSE shape: [16773] values: [100.253067 78.0984497 288.986786 ... 30.5049648 11.3987141 93.1522217]
# Final loss shape: [] value: 4490.63818
# Per-sample MSE shape: [16773] values: [1511.88 159.535721 208.732635 ... 76.8240356 326.483673 2646.0625]
# Final loss shape: [] value: 1242.34924
# Per-sample MSE shape: [16773] values: [139.437866 648.293091 203.205231 ... 181.13414 66.8932343 89.0485382]
# Final loss shape: [] value: 13647.6523
# Per-sample MSE shape: [16773] values: [717.546936 7.7994771 0 ... 13.4979477 74.5971756 4825.479]
# Final loss shape: [] value: 567.610229
# Per-sample MSE shape: [16773] values: [154.486191 0 75.6552 ... 99.9530945 0 177.044388]
# Final loss shape: [] value: 3662.62256
# Per-sample MSE shape: [16773] values: [107.736076 1587.25793 100.126564 ... 193616.594 86.2405777 58.1538506]
# Final loss shape: [] value: 1196.61328
# Per-sample MSE shape: [16773] values: [281.965302 171.802185 1815.97656 ... 26.5394936 267.117218 140.827]
# Final loss shape: [] value: 3360.32153
# Per-sample MSE shape: [16773] values: [75.1837921 8.83858204 116.829689 ... 78.2019806 43.327076 152.893982]
# Final loss shape: [] value: 778.559082
# Per-sample MSE shape: [16773] values: [13.1599 69.8307724 478.853 ... 4.32276964 514.266174 1371.71521]
# Final loss shape: [] value: 63516.4727
# Per-sample MSE shape: [16773] values: [432.485321 44.2188644 178.926025 ... 246.361496 215.148285 591.725952]
# Final loss shape: [] value: 2055.01855
# Per-sample MSE shape: [16773] values: [234.706467 4.00967741 142.584244 ... 73.0975723 89.3018646 527.659302]
# Final loss shape: [] value: 15651.8184
# Per-sample MSE shape: [16773] values: [256.338776 514.868469 149.380402 ... 0 86.112793 183.401688]
# Final loss shape: [] value: 548.318
# Per-sample MSE shape: [16773] values: [149.363983 157.258804 14.6330147 ... 20.5724277 258.878937 82.4808]
# Final loss shape: [] value: 18072.0742
# Per-sample MSE shape: [16773] values: [77.0546722 0 63.3776436 ... 345.231567 120.083771 80.7472153]
# Final loss shape: [] value: 43656.4414
# Per-sample MSE shape: [16773] values: [25.7625618 0 55.376667 ... 238.544342 56.3902283 71.5920868]
# Final loss shape: [] value: 1244.79895
# Per-sample MSE shape: [16773] values: [352.792511 130.397125 583.154358 ... 32.074 207.138 111.081978]
# Final loss shape: [] value: 2384.85083
# Per-sample MSE shape: [16773] values: [170.997253 29.3870125 293.593781 ... 81.7104416 97.8046799 109.855164]
# Final loss shape: [] value: 5466.40332
# Per-sample MSE shape: [16773] values: [7.77957201 184.365143 374.915833 ... 364.98468 0 49.1040573]
# Final loss shape: [] value: 27539.9453
# Per-sample MSE shape: [16773] values: [51.2294693 597.166138 124.363777 ... 82.5581131 105.130547 66.1736832]
# Final loss shape: [] value: 6295.58
# Per-sample MSE shape: [16773] values: [89.1971283 131.802963 63.6072044 ... 12089.9707 137.009705 317.553528]
# Final loss shape: [] value: 913.962341
# Per-sample MSE shape: [16773] values: [379.954224 159.225754 100.138824 ... 32.1207504 74.8807144 42.3937645]
# Final loss shape: [] value: 118145.891
# Per-sample MSE shape: [16773] values: [146.079834 799.811279 193.62558 ... 418.594574 90.9657516 609.690552]
# Final loss shape: [] value: 869.900146
# Per-sample MSE shape: [16773] values: [454.441223 13.0829496 75.917923 ... 51.58284 605.444031 113.129494]
# Final loss shape: [] value: 1166.47681
# Per-sample MSE shape: [16773] values: [32.3370895 587.381653 122.949524 ... 12.0508766 43.895504 126.767654]
# Final loss shape: [] value: 3094.90649
# Per-sample MSE shape: [16773] values: [681.144104 0 54.7695427 ... 16.3499241 219.515076 170.278625]
# Final loss shape: [] value: 564.950928
# Per-sample MSE shape: [16773] values: [248.756317 161.39032 875.229858 ... 0 119.695236 436.016327]
# Final loss shape: [] value: 30655.7891
# Per-sample MSE shape: [18] values: [76.9993 223.137283 21.9703484 ... 651.237793 97.0864 116.133232]
# Final loss shape: [] value: 196.271912
# loss [2184.2202, 1295.016, 1018.7711, 4374.3584, 11408397.0, 47026.2, 3540.2717, 80022.164, 1079.5414, 1080.3032, 3794.5325, 2970.916, 3772.7986, 7650.1885, 5564.514, 13036.235, 2344.7065, 594.7979, 8808.885, 7002.463, 1716.8799, 833.2983, 983.36163, 9189.194, 4491.7847, 1242.7609, 13648.824, 572.29034, 3663.8467, 1199.4224, 3361.6482, 784.2074, 63516.766, 2057.0403, 15652.419, 550.8781, 18072.639, 43656.523, 1249.1469, 2386.5593, 5467.348, 27540.36, 6296.521, 917.2462, 118146.1, 874.16986, 1168.1158, 3096.2559, 565.90594, 30656.195, 203.44789]

# %%
def recon_loss(x_true, x_pred):
    # Mean Squared Error
    recon = tf.reduce_mean(tf.square(x_true - x_pred))
    return recon

all_recon_losses = []

for epoch in range(EPOCHS):
    print(f"\nEpoch {epoch+1}/{EPOCHS}")
    
    # Shuffle training data
    idx = np.arange(len(X_train))
    np.random.shuffle(idx)
    X_train_shuffled = X_train[idx]
    
    num_batches = int(np.ceil(len(X_train) / BATCH_SIZE))
    
    for i in range(num_batches):
        batch_X = X_train_shuffled[i*BATCH_SIZE:(i+1)*BATCH_SIZE]
        
        # Model predictions
        batch_pred = ae(batch_X, training=False)

        # Compute reconstruction loss per sample
        recon_val = tf.reduce_mean(tf.square(tf.constant(batch_X, dtype=tf.float32) - batch_pred), axis=1)

        # Convert to numpy and extend the global array
        all_recon_losses.extend(recon_val.numpy())

        print(f"  Batch {i+1}/{num_batches} | Batch Recon Mean = {np.mean(recon_val.numpy()):.4f}")

print(f"Total samples recorded: {len(all_recon_losses)}")
# Out:
# Epoch 1/1
#   Batch 1/1639 | Batch Recon Mean = 352.5190
#   Batch 2/1639 | Batch Recon Mean = 756.3524
#   Batch 3/1639 | Batch Recon Mean = 405.0544
#   Batch 4/1639 | Batch Recon Mean = 352.4970
#   Batch 5/1639 | Batch Recon Mean = 361.9637
#   Batch 6/1639 | Batch Recon Mean = 404.6236
#   Batch 7/1639 | Batch Recon Mean = 400.2768
#   Batch 8/1639 | Batch Recon Mean = 425.4569
#   Batch 9/1639 | Batch Recon Mean = 346.7185
#   Batch 10/1639 | Batch Recon Mean = 425.2041
#   Batch 11/1639 | Batch Recon Mean = 3406.2261
#   Batch 12/1639 | Batch Recon Mean = 3232.5256
#   Batch 13/1639 | Batch Recon Mean = 477.9403
#   Batch 14/1639 | Batch Recon Mean = 687.3617
#   Batch 15/1639 | Batch Recon Mean = 334.0822
#   Batch 16/1639 | Batch Recon Mean = 531.6884
#   Batch 17/1639 | Batch Recon Mean = 344.9128
#   Batch 18/1639 | Batch Recon Mean = 440.1750
#   Batch 19/1639 | Batch Recon Mean = 473.9649
#   Batch 20/1639 | Batch Recon Mean = 430.2592
#   Batch 21/1639 | Batch Recon Mean = 439.6924
#   Batch 22/1639 | Batch Recon Mean = 360.1818
#   Batch 23/1639 | Batch Recon Mean = 955.1238
#   Batch 24/1639 | Batch Recon Mean = 1217.5420
#   Batch 25/1639 | Batch Recon Mean = 312.1211
#   Batch 26/1639 | Batch Recon Mean = 381.7300
#   Batch 27/1639 | Batch Recon Mean = 604.0725
#   Batch 28/1639 | Batch Recon Mean = 496.7639
#   Batch 29/1639 | Batch Recon Mean = 4047.1704
#   Batch 30/1639 | Batch Recon Mean = 583.6866
#   Batch 31/1639 | Batch Recon Mean = 368.1581
#   Batch 32/1639 | Batch Recon Mean = 444.5845
#   Batch 33/1639 | Batch Recon Mean = 447.0848
#   Batch 34/1639 | Batch Recon Mean = 368.8114
#   Batch 35/1639 | Batch Recon Mean = 13275.1260
#   Batch 36/1639 | Batch Recon Mean = 401.1336
#   Batch 37/1639 | Batch Recon Mean = 593.3901
#   Batch 38/1639 | Batch Recon Mean = 560.2329
#   Batch 39/1639 | Batch Recon Mean = 191790.3438
#   Batch 40/1639 | Batch Recon Mean = 407.7784
#   Batch 41/1639 | Batch Recon Mean = 1418.1885
#   Batch 42/1639 | Batch Recon Mean = 574.8003
#   Batch 43/1639 | Batch Recon Mean = 492.2064
#   Batch 44/1639 | Batch Recon Mean = 386.2450
#   Batch 45/1639 | Batch Recon Mean = 1084.6063
#   Batch 46/1639 | Batch Recon Mean = 435.8191
#   Batch 47/1639 | Batch Recon Mean = 542.9376
#   Batch 48/1639 | Batch Recon Mean = 828.8674
#   Batch 49/1639 | Batch Recon Mean = 461.6977
#   Batch 50/1639 | Batch Recon Mean = 952.3431
#   Batch 51/1639 | Batch Recon Mean = 1707.9552
#   Batch 52/1639 | Batch Recon Mean = 422.8035
#   Batch 53/1639 | Batch Recon Mean = 6795.7329
#   Batch 54/1639 | Batch Recon Mean = 443.1913
#   Batch 55/1639 | Batch Recon Mean = 475.7269
#   Batch 56/1639 | Batch Recon Mean = 1931.8783
#   Batch 57/1639 | Batch Recon Mean = 436.1874
#   Batch 58/1639 | Batch Recon Mean = 351.9912
#   Batch 59/1639 | Batch Recon Mean = 331.7489
#   Batch 60/1639 | Batch Recon Mean = 465.0198
#   Batch 61/1639 | Batch Recon Mean = 746.2179
#   Batch 62/1639 | Batch Recon Mean = 546.4540
#   Batch 63/1639 | Batch Recon Mean = 346.0620
#   Batch 64/1639 | Batch Recon Mean = 393.2964
#   Batch 65/1639 | Batch Recon Mean = 416.8103
#   Batch 66/1639 | Batch Recon Mean = 380.0526
#   Batch 67/1639 | Batch Recon Mean = 392.6676
#   Batch 68/1639 | Batch Recon Mean = 354.5162
#   Batch 69/1639 | Batch Recon Mean = 323.1706
#   Batch 70/1639 | Batch Recon Mean = 443.3474
#   Batch 71/1639 | Batch Recon Mean = 494.1461
#   Batch 72/1639 | Batch Recon Mean = 414.3672
#   Batch 73/1639 | Batch Recon Mean = 868.7822
#   Batch 74/1639 | Batch Recon Mean = 19305.9902
#   Batch 75/1639 | Batch Recon Mean = 431.6317
#   Batch 76/1639 | Batch Recon Mean = 524.9589
#   Batch 77/1639 | Batch Recon Mean = 6041.9595
#   Batch 78/1639 | Batch Recon Mean = 755.1208
#   Batch 79/1639 | Batch Recon Mean = 651.3185
#   Batch 80/1639 | Batch Recon Mean = 610.6443
#   Batch 81/1639 | Batch Recon Mean = 2081.0356
#   Batch 82/1639 | Batch Recon Mean = 835.6866
#   Batch 83/1639 | Batch Recon Mean = 338.1227
#   Batch 84/1639 | Batch Recon Mean = 400.7870
#   Batch 85/1639 | Batch Recon Mean = 381.0245
#   Batch 86/1639 | Batch Recon Mean = 375.8572
#   Batch 87/1639 | Batch Recon Mean = 785.4941
#   Batch 88/1639 | Batch Recon Mean = 526.4568
#   Batch 89/1639 | Batch Recon Mean = 374.8401
#   Batch 90/1639 | Batch Recon Mean = 4591.5073
#   Batch 91/1639 | Batch Recon Mean = 504.8399
#   Batch 92/1639 | Batch Recon Mean = 613.6956
#   Batch 93/1639 | Batch Recon Mean = 362.6652
#   Batch 94/1639 | Batch Recon Mean = 3968.6665
#   Batch 95/1639 | Batch Recon Mean = 830.5682
#   Batch 96/1639 | Batch Recon Mean = 550.5623
#   Batch 97/1639 | Batch Recon Mean = 589.7761
#   Batch 98/1639 | Batch Recon Mean = 2937.2808
#   Batch 99/1639 | Batch Recon Mean = 514.3239
#   Batch 100/1639 | Batch Recon Mean = 374694.4375
#   Batch 101/1639 | Batch Recon Mean = 444.2386
#   Batch 102/1639 | Batch Recon Mean = 805.7711
#   Batch 103/1639 | Batch Recon Mean = 1216.0952
#   Batch 104/1639 | Batch Recon Mean = 438.9069
#   Batch 105/1639 | Batch Recon Mean = 556.3964
#   Batch 106/1639 | Batch Recon Mean = 536.8282
#   Batch 107/1639 | Batch Recon Mean = 1138.9381
#   Batch 108/1639 | Batch Recon Mean = 350.4747
#   Batch 109/1639 | Batch Recon Mean = 351.8837
#   Batch 110/1639 | Batch Recon Mean = 387.1420
#   Batch 111/1639 | Batch Recon Mean = 432.9545
#   Batch 112/1639 | Batch Recon Mean = 526.7427
#   Batch 113/1639 | Batch Recon Mean = 1056.0378
#   Batch 114/1639 | Batch Recon Mean = 646.2406
#   Batch 115/1639 | Batch Recon Mean = 381.7964
#   Batch 116/1639 | Batch Recon Mean = 346.9586
#   Batch 117/1639 | Batch Recon Mean = 383.7719
#   Batch 118/1639 | Batch Recon Mean = 377.6237
#   Batch 119/1639 | Batch Recon Mean = 492598.5312
#   Batch 120/1639 | Batch Recon Mean = 333.7216
#   Batch 121/1639 | Batch Recon Mean = 431.1953
#   Batch 122/1639 | Batch Recon Mean = 373.7520
#   Batch 123/1639 | Batch Recon Mean = 15900.8086
#   Batch 124/1639 | Batch Recon Mean = 4181.6206
#   Batch 125/1639 | Batch Recon Mean = 447.3560
#   Batch 126/1639 | Batch Recon Mean = 318.9448
#   Batch 127/1639 | Batch Recon Mean = 530.5208
#   Batch 128/1639 | Batch Recon Mean = 293.2153
#   Batch 129/1639 | Batch Recon Mean = 348.3783
#   Batch 130/1639 | Batch Recon Mean = 458.3734
#   Batch 131/1639 | Batch Recon Mean = 293.7853
#   Batch 132/1639 | Batch Recon Mean = 99350.8438
#   Batch 133/1639 | Batch Recon Mean = 2218.3562
#   Batch 134/1639 | Batch Recon Mean = 565.7479
#   Batch 135/1639 | Batch Recon Mean = 374.5939
#   Batch 136/1639 | Batch Recon Mean = 494.0023
#   Batch 137/1639 | Batch Recon Mean = 396.9385
#   Batch 138/1639 | Batch Recon Mean = 428.5612
#   Batch 139/1639 | Batch Recon Mean = 1397.6769
#   Batch 140/1639 | Batch Recon Mean = 442.6513
#   Batch 141/1639 | Batch Recon Mean = 373.3179
#   Batch 142/1639 | Batch Recon Mean = 442.2618
#   Batch 143/1639 | Batch Recon Mean = 521.0590
#   Batch 144/1639 | Batch Recon Mean = 414.5819
#   Batch 145/1639 | Batch Recon Mean = 425.4536
#   Batch 146/1639 | Batch Recon Mean = 335.7179
#   Batch 147/1639 | Batch Recon Mean = 533.8635
#   Batch 148/1639 | Batch Recon Mean = 322.2750
#   Batch 149/1639 | Batch Recon Mean = 390.7477
#   Batch 150/1639 | Batch Recon Mean = 1241.4868
#   Batch 151/1639 | Batch Recon Mean = 408.9223
#   Batch 152/1639 | Batch Recon Mean = 419.1021
#   Batch 153/1639 | Batch Recon Mean = 879.0737
#   Batch 154/1639 | Batch Recon Mean = 468.2339
#   Batch 155/1639 | Batch Recon Mean = 513.3489
#   Batch 156/1639 | Batch Recon Mean = 399.1960
#   Batch 157/1639 | Batch Recon Mean = 730.2776
#   Batch 158/1639 | Batch Recon Mean = 490.1868
#   Batch 159/1639 | Batch Recon Mean = 452.4271
#   Batch 160/1639 | Batch Recon Mean = 667.7972
#   Batch 161/1639 | Batch Recon Mean = 421.2047
#   Batch 162/1639 | Batch Recon Mean = 10485.0166
#   Batch 163/1639 | Batch Recon Mean = 490.1670
#   Batch 164/1639 | Batch Recon Mean = 960.2900
#   Batch 165/1639 | Batch Recon Mean = 587.5800
#   Batch 166/1639 | Batch Recon Mean = 2662.7554
#   Batch 167/1639 | Batch Recon Mean = 575.1491
#   Batch 168/1639 | Batch Recon Mean = 549.4766
#   Batch 169/1639 | Batch Recon Mean = 472.8457
#   Batch 170/1639 | Batch Recon Mean = 602.4162
#   Batch 171/1639 | Batch Recon Mean = 368.9069
#   Batch 172/1639 | Batch Recon Mean = 408.4789
#   Batch 173/1639 | Batch Recon Mean = 648.3532
#   Batch 174/1639 | Batch Recon Mean = 356.9529
#   Batch 175/1639 | Batch Recon Mean = 700.4450
#   Batch 176/1639 | Batch Recon Mean = 468.7061
#   Batch 177/1639 | Batch Recon Mean = 365.9746
#   Batch 178/1639 | Batch Recon Mean = 415.0599
#   Batch 179/1639 | Batch Recon Mean = 1344664.7500
#   Batch 180/1639 | Batch Recon Mean = 578.7222
#   Batch 181/1639 | Batch Recon Mean = 1735.1276
#   Batch 182/1639 | Batch Recon Mean = 403.0487
#   Batch 183/1639 | Batch Recon Mean = 520.2438
#   Batch 184/1639 | Batch Recon Mean = 535.1810
#   Batch 185/1639 | Batch Recon Mean = 201453.1875
#   Batch 186/1639 | Batch Recon Mean = 358.8712
#   Batch 187/1639 | Batch Recon Mean = 5733.4126
#   Batch 188/1639 | Batch Recon Mean = 325.0750
#   Batch 189/1639 | Batch Recon Mean = 385.3265
#   Batch 190/1639 | Batch Recon Mean = 346.1180
#   Batch 191/1639 | Batch Recon Mean = 690.4952
#   Batch 192/1639 | Batch Recon Mean = 456.9980
#   Batch 193/1639 | Batch Recon Mean = 505.8766
#   Batch 194/1639 | Batch Recon Mean = 2723.9517
#   Batch 195/1639 | Batch Recon Mean = 364.0409
#   Batch 196/1639 | Batch Recon Mean = 1087.1663
#   Batch 197/1639 | Batch Recon Mean = 494.2039
#   Batch 198/1639 | Batch Recon Mean = 398.9339
#   Batch 199/1639 | Batch Recon Mean = 507.5046
#   Batch 200/1639 | Batch Recon Mean = 454.2441
#   Batch 201/1639 | Batch Recon Mean = 422.3505
#   Batch 202/1639 | Batch Recon Mean = 904.6908
#   Batch 203/1639 | Batch Recon Mean = 1014.8945
#   Batch 204/1639 | Batch Recon Mean = 396.2774
#   Batch 205/1639 | Batch Recon Mean = 629.7104
#   Batch 206/1639 | Batch Recon Mean = 491.6273
#   Batch 207/1639 | Batch Recon Mean = 632.9794
#   Batch 208/1639 | Batch Recon Mean = 807.0968
#   Batch 209/1639 | Batch Recon Mean = 716.5533
#   Batch 210/1639 | Batch Recon Mean = 2189.4546
#   Batch 211/1639 | Batch Recon Mean = 379.0828
#   Batch 212/1639 | Batch Recon Mean = 434.9720
#   Batch 213/1639 | Batch Recon Mean = 1322.9459
#   Batch 214/1639 | Batch Recon Mean = 578.2172
#   Batch 215/1639 | Batch Recon Mean = 19291.5000
#   Batch 216/1639 | Batch Recon Mean = 500.9218
#   Batch 217/1639 | Batch Recon Mean = 879.4343
#   Batch 218/1639 | Batch Recon Mean = 308.9157
#   Batch 219/1639 | Batch Recon Mean = 5902.1572
#   Batch 220/1639 | Batch Recon Mean = 199884.4375
#   Batch 221/1639 | Batch Recon Mean = 421.3971
#   Batch 222/1639 | Batch Recon Mean = 3415.2512
#   Batch 223/1639 | Batch Recon Mean = 451.0280
#   Batch 224/1639 | Batch Recon Mean = 473.2113
#   Batch 225/1639 | Batch Recon Mean = 549.3217
#   Batch 226/1639 | Batch Recon Mean = 530.9839
#   Batch 227/1639 | Batch Recon Mean = 328674.1250
#   Batch 228/1639 | Batch Recon Mean = 332.7794
#   Batch 229/1639 | Batch Recon Mean = 988.9750
#   Batch 230/1639 | Batch Recon Mean = 546.7418
#   Batch 231/1639 | Batch Recon Mean = 363.2619
#   Batch 232/1639 | Batch Recon Mean = 382.8813
#   Batch 233/1639 | Batch Recon Mean = 470.9095
#   Batch 234/1639 | Batch Recon Mean = 589.8806
#   Batch 235/1639 | Batch Recon Mean = 851.7124
#   Batch 236/1639 | Batch Recon Mean = 321.7053
#   Batch 237/1639 | Batch Recon Mean = 420.2737
#   Batch 238/1639 | Batch Recon Mean = 490.7550
#   Batch 239/1639 | Batch Recon Mean = 394.2995
#   Batch 240/1639 | Batch Recon Mean = 376.0146
#   Batch 241/1639 | Batch Recon Mean = 933.2663
#   Batch 242/1639 | Batch Recon Mean = 476.0359
#   Batch 243/1639 | Batch Recon Mean = 1650.9968
#   Batch 244/1639 | Batch Recon Mean = 572.0457
#   Batch 245/1639 | Batch Recon Mean = 414.3521
#   Batch 246/1639 | Batch Recon Mean = 399.5958
#   Batch 247/1639 | Batch Recon Mean = 299.4639
#   Batch 248/1639 | Batch Recon Mean = 500.9268
#   Batch 249/1639 | Batch Recon Mean = 472.0888
#   Batch 250/1639 | Batch Recon Mean = 510.7634
#   Batch 251/1639 | Batch Recon Mean = 8929.1328
#   Batch 252/1639 | Batch Recon Mean = 343.6964
#   Batch 253/1639 | Batch Recon Mean = 301.6931
#   Batch 254/1639 | Batch Recon Mean = 590.3052
#   Batch 255/1639 | Batch Recon Mean = 567.1588
#   Batch 256/1639 | Batch Recon Mean = 242.3356
#   Batch 257/1639 | Batch Recon Mean = 1136.5823
#   Batch 258/1639 | Batch Recon Mean = 579.4104
#   Batch 259/1639 | Batch Recon Mean = 473.8474
#   Batch 260/1639 | Batch Recon Mean = 885.9662
#   Batch 261/1639 | Batch Recon Mean = 1029.5590
#   Batch 262/1639 | Batch Recon Mean = 405.6182
#   Batch 263/1639 | Batch Recon Mean = 390.6671
#   Batch 264/1639 | Batch Recon Mean = 1428.7628
#   Batch 265/1639 | Batch Recon Mean = 368.2795
#   Batch 266/1639 | Batch Recon Mean = 467.8301
#   Batch 267/1639 | Batch Recon Mean = 16076.8135
#   Batch 268/1639 | Batch Recon Mean = 1106.0557
#   Batch 269/1639 | Batch Recon Mean = 395.1857
#   Batch 270/1639 | Batch Recon Mean = 770.6127
#   Batch 271/1639 | Batch Recon Mean = 389.4847
#   Batch 272/1639 | Batch Recon Mean = 712.5715
#   Batch 273/1639 | Batch Recon Mean = 686.3140
#   Batch 274/1639 | Batch Recon Mean = 1852.2939
#   Batch 275/1639 | Batch Recon Mean = 378.4003
#   Batch 276/1639 | Batch Recon Mean = 712.9252
#   Batch 277/1639 | Batch Recon Mean = 803.0547
#   Batch 278/1639 | Batch Recon Mean = 969.5515
#   Batch 279/1639 | Batch Recon Mean = 412.4614
#   Batch 280/1639 | Batch Recon Mean = 482.9923
#   Batch 281/1639 | Batch Recon Mean = 307.1155
#   Batch 282/1639 | Batch Recon Mean = 440.7150
#   Batch 283/1639 | Batch Recon Mean = 504.2912
#   Batch 284/1639 | Batch Recon Mean = 432.7532
#   Batch 285/1639 | Batch Recon Mean = 550.3264
#   Batch 286/1639 | Batch Recon Mean = 969.4362
#   Batch 287/1639 | Batch Recon Mean = 519.1847
#   Batch 288/1639 | Batch Recon Mean = 506.7619
#   Batch 289/1639 | Batch Recon Mean = 360.4728
#   Batch 290/1639 | Batch Recon Mean = 835.8958
#   Batch 291/1639 | Batch Recon Mean = 436.1426
#   Batch 292/1639 | Batch Recon Mean = 428.1573
#   Batch 293/1639 | Batch Recon Mean = 12922.8975
#   Batch 294/1639 | Batch Recon Mean = 425.9587
#   Batch 295/1639 | Batch Recon Mean = 539.4758
#   Batch 296/1639 | Batch Recon Mean = 2728.9041
#   Batch 297/1639 | Batch Recon Mean = 402.6265
#   Batch 298/1639 | Batch Recon Mean = 1038.6511
#   Batch 299/1639 | Batch Recon Mean = 68921.5703
#   Batch 300/1639 | Batch Recon Mean = 639.2384
#   Batch 301/1639 | Batch Recon Mean = 475.7636
#   Batch 302/1639 | Batch Recon Mean = 400.3890
#   Batch 303/1639 | Batch Recon Mean = 453.9328
#   Batch 304/1639 | Batch Recon Mean = 353.1934
#   Batch 305/1639 | Batch Recon Mean = 394.4271
#   Batch 306/1639 | Batch Recon Mean = 340.4229
#   Batch 307/1639 | Batch Recon Mean = 397.9760
#   Batch 308/1639 | Batch Recon Mean = 3777.5735
#   Batch 309/1639 | Batch Recon Mean = 434.8896
#   Batch 310/1639 | Batch Recon Mean = 371.8497
#   Batch 311/1639 | Batch Recon Mean = 471.6528
#   Batch 312/1639 | Batch Recon Mean = 482.9977
#   Batch 313/1639 | Batch Recon Mean = 365.8979
#   Batch 314/1639 | Batch Recon Mean = 368.0666
#   Batch 315/1639 | Batch Recon Mean = 429.4534
#   Batch 316/1639 | Batch Recon Mean = 378.4701
#   Batch 317/1639 | Batch Recon Mean = 512.7166
#   Batch 318/1639 | Batch Recon Mean = 395.4740
#   Batch 319/1639 | Batch Recon Mean = 533.3857
#   Batch 320/1639 | Batch Recon Mean = 794.0449
#   Batch 321/1639 | Batch Recon Mean = 482.8174
#   Batch 322/1639 | Batch Recon Mean = 1808.7546
#   Batch 323/1639 | Batch Recon Mean = 387.9941
#   Batch 324/1639 | Batch Recon Mean = 535.7672
#   Batch 325/1639 | Batch Recon Mean = 4440.4199
#   Batch 326/1639 | Batch Recon Mean = 339.5571
#   Batch 327/1639 | Batch Recon Mean = 2063.3491
#   Batch 328/1639 | Batch Recon Mean = 568.8689
#   Batch 329/1639 | Batch Recon Mean = 483.5706
#   Batch 330/1639 | Batch Recon Mean = 588.6435
#   Batch 331/1639 | Batch Recon Mean = 442.0385
#   Batch 332/1639 | Batch Recon Mean = 482.1108
#   Batch 333/1639 | Batch Recon Mean = 466.3465
#   Batch 334/1639 | Batch Recon Mean = 550.2793
#   Batch 335/1639 | Batch Recon Mean = 5645.0513
#   Batch 336/1639 | Batch Recon Mean = 690.3162
#   Batch 337/1639 | Batch Recon Mean = 1245.6464
#   Batch 338/1639 | Batch Recon Mean = 392.6525
#   Batch 339/1639 | Batch Recon Mean = 716.6229
#   Batch 340/1639 | Batch Recon Mean = 358.0590
#   Batch 341/1639 | Batch Recon Mean = 333.8309
#   Batch 342/1639 | Batch Recon Mean = 503.5393
#   Batch 343/1639 | Batch Recon Mean = 611.4221
#   Batch 344/1639 | Batch Recon Mean = 3779.6362
#   Batch 345/1639 | Batch Recon Mean = 849.5366
#   Batch 346/1639 | Batch Recon Mean = 420.2712
#   Batch 347/1639 | Batch Recon Mean = 390.1803
#   Batch 348/1639 | Batch Recon Mean = 486.0376
#   Batch 349/1639 | Batch Recon Mean = 426.5161
#   Batch 350/1639 | Batch Recon Mean = 867.1641
#   Batch 351/1639 | Batch Recon Mean = 426.5355
#   Batch 352/1639 | Batch Recon Mean = 410.0161
#   Batch 353/1639 | Batch Recon Mean = 612.3811
#   Batch 354/1639 | Batch Recon Mean = 341.5915
#   Batch 355/1639 | Batch Recon Mean = 411.0626
#   Batch 356/1639 | Batch Recon Mean = 486.2656
#   Batch 357/1639 | Batch Recon Mean = 634.4120
#   Batch 358/1639 | Batch Recon Mean = 1001.2963
#   Batch 359/1639 | Batch Recon Mean = 2072.4248
#   Batch 360/1639 | Batch Recon Mean = 3307.3772
#   Batch 361/1639 | Batch Recon Mean = 690.8981
#   Batch 362/1639 | Batch Recon Mean = 172390.5938
#   Batch 363/1639 | Batch Recon Mean = 548.1436
#   Batch 364/1639 | Batch Recon Mean = 314.2473
#   Batch 365/1639 | Batch Recon Mean = 361.8843
#   Batch 366/1639 | Batch Recon Mean = 566.6576
#   Batch 367/1639 | Batch Recon Mean = 386.7753
#   Batch 368/1639 | Batch Recon Mean = 335.6519
#   Batch 369/1639 | Batch Recon Mean = 395.2333
#   Batch 370/1639 | Batch Recon Mean = 1542.9799
#   Batch 371/1639 | Batch Recon Mean = 459.9101
#   Batch 372/1639 | Batch Recon Mean = 628.0502
#   Batch 373/1639 | Batch Recon Mean = 1036.8461
#   Batch 374/1639 | Batch Recon Mean = 513.0317
#   Batch 375/1639 | Batch Recon Mean = 789.2755
#   Batch 376/1639 | Batch Recon Mean = 526.5245
#   Batch 377/1639 | Batch Recon Mean = 435.1627
#   Batch 378/1639 | Batch Recon Mean = 365.2245
#   Batch 379/1639 | Batch Recon Mean = 550.3302
#   Batch 380/1639 | Batch Recon Mean = 26233.2539
#   Batch 381/1639 | Batch Recon Mean = 388.9168
#   Batch 382/1639 | Batch Recon Mean = 635.4957
#   Batch 383/1639 | Batch Recon Mean = 511.9237
#   Batch 384/1639 | Batch Recon Mean = 7660.3525
#   Batch 385/1639 | Batch Recon Mean = 426.8637
#   Batch 386/1639 | Batch Recon Mean = 647.4666
#   Batch 387/1639 | Batch Recon Mean = 16749.0000
#   Batch 388/1639 | Batch Recon Mean = 464.4963
#   Batch 389/1639 | Batch Recon Mean = 342.2003
#   Batch 390/1639 | Batch Recon Mean = 363.3681
#   Batch 391/1639 | Batch Recon Mean = 446.6405
#   Batch 392/1639 | Batch Recon Mean = 465.6905
#   Batch 393/1639 | Batch Recon Mean = 454.5446
#   Batch 394/1639 | Batch Recon Mean = 529.8895
#   Batch 395/1639 | Batch Recon Mean = 1094.7747
#   Batch 396/1639 | Batch Recon Mean = 47120.5234
#   Batch 397/1639 | Batch Recon Mean = 7694.8765
#   Batch 398/1639 | Batch Recon Mean = 383.6518
#   Batch 399/1639 | Batch Recon Mean = 332.8112
#   Batch 400/1639 | Batch Recon Mean = 483.9815
#   Batch 401/1639 | Batch Recon Mean = 1271.1268
#   Batch 402/1639 | Batch Recon Mean = 539.3219
#   Batch 403/1639 | Batch Recon Mean = 63913.4219
#   Batch 404/1639 | Batch Recon Mean = 310.6341
#   Batch 405/1639 | Batch Recon Mean = 614.5961
#   Batch 406/1639 | Batch Recon Mean = 433.7869
#   Batch 407/1639 | Batch Recon Mean = 369.1978
#   Batch 408/1639 | Batch Recon Mean = 465.0717
#   Batch 409/1639 | Batch Recon Mean = 534.2054
#   Batch 410/1639 | Batch Recon Mean = 557.8160
#   Batch 411/1639 | Batch Recon Mean = 319.7492
#   Batch 412/1639 | Batch Recon Mean = 462.0566
#   Batch 413/1639 | Batch Recon Mean = 435.9909
#   Batch 414/1639 | Batch Recon Mean = 11645.5020
#   Batch 415/1639 | Batch Recon Mean = 426.2515
#   Batch 416/1639 | Batch Recon Mean = 582.1041
#   Batch 417/1639 | Batch Recon Mean = 333.6426
#   Batch 418/1639 | Batch Recon Mean = 367.0618
#   Batch 419/1639 | Batch Recon Mean = 336.7673
#   Batch 420/1639 | Batch Recon Mean = 440.8168
#   Batch 421/1639 | Batch Recon Mean = 738.5787
#   Batch 422/1639 | Batch Recon Mean = 848.1891
#   Batch 423/1639 | Batch Recon Mean = 420.5546
#   Batch 424/1639 | Batch Recon Mean = 1910.1812
#   Batch 425/1639 | Batch Recon Mean = 416.6086
#   Batch 426/1639 | Batch Recon Mean = 357.4554
#   Batch 427/1639 | Batch Recon Mean = 600.8380
#   Batch 428/1639 | Batch Recon Mean = 394.7303
#   Batch 429/1639 | Batch Recon Mean = 424.0294
#   Batch 430/1639 | Batch Recon Mean = 1639119.1250
#   Batch 431/1639 | Batch Recon Mean = 489.5123
#   Batch 432/1639 | Batch Recon Mean = 506.0142
#   Batch 433/1639 | Batch Recon Mean = 17056.8223
#   Batch 434/1639 | Batch Recon Mean = 28995.8516
#   Batch 435/1639 | Batch Recon Mean = 37841.8789
#   Batch 436/1639 | Batch Recon Mean = 628.9310
#   Batch 437/1639 | Batch Recon Mean = 3190.0835
#   Batch 438/1639 | Batch Recon Mean = 935.5486
#   Batch 439/1639 | Batch Recon Mean = 4106.2510
#   Batch 440/1639 | Batch Recon Mean = 414.4799
#   Batch 441/1639 | Batch Recon Mean = 497.2188
#   Batch 442/1639 | Batch Recon Mean = 34643.1602
#   Batch 443/1639 | Batch Recon Mean = 534.5952
#   Batch 444/1639 | Batch Recon Mean = 396.0888
#   Batch 445/1639 | Batch Recon Mean = 360.4993
#   Batch 446/1639 | Batch Recon Mean = 324.7782
#   Batch 447/1639 | Batch Recon Mean = 530.1772
#   Batch 448/1639 | Batch Recon Mean = 824.1528
#   Batch 449/1639 | Batch Recon Mean = 674.8275
#   Batch 450/1639 | Batch Recon Mean = 359.7094
#   Batch 451/1639 | Batch Recon Mean = 344.6964
#   Batch 452/1639 | Batch Recon Mean = 245.8878
#   Batch 453/1639 | Batch Recon Mean = 386.3187
#   Batch 454/1639 | Batch Recon Mean = 498.8533
#   Batch 455/1639 | Batch Recon Mean = 490.7217
#   Batch 456/1639 | Batch Recon Mean = 363.7816
#   Batch 457/1639 | Batch Recon Mean = 484.3572
#   Batch 458/1639 | Batch Recon Mean = 870.3937
#   Batch 459/1639 | Batch Recon Mean = 541.5472
#   Batch 460/1639 | Batch Recon Mean = 616.7834
#   Batch 461/1639 | Batch Recon Mean = 389.6113
#   Batch 462/1639 | Batch Recon Mean = 906.7512
#   Batch 463/1639 | Batch Recon Mean = 671.5679
#   Batch 464/1639 | Batch Recon Mean = 2430.0815
#   Batch 465/1639 | Batch Recon Mean = 412.9107
#   Batch 466/1639 | Batch Recon Mean = 1124.7584
#   Batch 467/1639 | Batch Recon Mean = 294.3824
#   Batch 468/1639 | Batch Recon Mean = 804.0184
#   Batch 469/1639 | Batch Recon Mean = 1666.4312
#   Batch 470/1639 | Batch Recon Mean = 487.6484
#   Batch 471/1639 | Batch Recon Mean = 384.7824
#   Batch 472/1639 | Batch Recon Mean = 420.8442
#   Batch 473/1639 | Batch Recon Mean = 259521.3594
#   Batch 474/1639 | Batch Recon Mean = 306.5828
#   Batch 475/1639 | Batch Recon Mean = 697.1420
#   Batch 476/1639 | Batch Recon Mean = 486.2598
#   Batch 477/1639 | Batch Recon Mean = 311.7000
#   Batch 478/1639 | Batch Recon Mean = 335.5818
#   Batch 479/1639 | Batch Recon Mean = 533.2358
#   Batch 480/1639 | Batch Recon Mean = 3664.8406
#   Batch 481/1639 | Batch Recon Mean = 305.1277
#   Batch 482/1639 | Batch Recon Mean = 478.9504
#   Batch 483/1639 | Batch Recon Mean = 3235.9160
#   Batch 484/1639 | Batch Recon Mean = 975.4006
#   Batch 485/1639 | Batch Recon Mean = 337.7625
#   Batch 486/1639 | Batch Recon Mean = 413.4220
#   Batch 487/1639 | Batch Recon Mean = 420.4429
#   Batch 488/1639 | Batch Recon Mean = 500.5980
#   Batch 489/1639 | Batch Recon Mean = 422.4851
#   Batch 490/1639 | Batch Recon Mean = 419.5287
#   Batch 491/1639 | Batch Recon Mean = 1679.1769
#   Batch 492/1639 | Batch Recon Mean = 442.4230
#   Batch 493/1639 | Batch Recon Mean = 1656.1388
#   Batch 494/1639 | Batch Recon Mean = 316.4824
#   Batch 495/1639 | Batch Recon Mean = 412.3448
#   Batch 496/1639 | Batch Recon Mean = 3730.4656
#   Batch 497/1639 | Batch Recon Mean = 426.1095
#   Batch 498/1639 | Batch Recon Mean = 3949.0068
#   Batch 499/1639 | Batch Recon Mean = 790.0295
#   Batch 500/1639 | Batch Recon Mean = 1055.2488
#   Batch 501/1639 | Batch Recon Mean = 351.2772
#   Batch 502/1639 | Batch Recon Mean = 416.4103
#   Batch 503/1639 | Batch Recon Mean = 1241.1628
#   Batch 504/1639 | Batch Recon Mean = 400.5804
#   Batch 505/1639 | Batch Recon Mean = 292.0233
#   Batch 506/1639 | Batch Recon Mean = 1460.5057
#   Batch 507/1639 | Batch Recon Mean = 1526.5800
#   Batch 508/1639 | Batch Recon Mean = 2386.2319
#   Batch 509/1639 | Batch Recon Mean = 38995.2852
#   Batch 510/1639 | Batch Recon Mean = 455.1818
#   Batch 511/1639 | Batch Recon Mean = 495.5855
#   Batch 512/1639 | Batch Recon Mean = 451.1042
#   Batch 513/1639 | Batch Recon Mean = 873.5283
#   Batch 514/1639 | Batch Recon Mean = 491.4991
#   Batch 515/1639 | Batch Recon Mean = 365.2620
#   Batch 516/1639 | Batch Recon Mean = 400.9813
#   Batch 517/1639 | Batch Recon Mean = 517.7229
#   Batch 518/1639 | Batch Recon Mean = 317.9676
#   Batch 519/1639 | Batch Recon Mean = 442.2012
#   Batch 520/1639 | Batch Recon Mean = 57626.2812
#   Batch 521/1639 | Batch Recon Mean = 490.2262
#   Batch 522/1639 | Batch Recon Mean = 10241.9102
#   Batch 523/1639 | Batch Recon Mean = 570.1687
#   Batch 524/1639 | Batch Recon Mean = 359.4788
#   Batch 525/1639 | Batch Recon Mean = 414.1975
#   Batch 526/1639 | Batch Recon Mean = 757.9811
#   Batch 527/1639 | Batch Recon Mean = 927.5013
#   Batch 528/1639 | Batch Recon Mean = 377.4685
#   Batch 529/1639 | Batch Recon Mean = 588.8624
#   Batch 530/1639 | Batch Recon Mean = 1492.6395
#   Batch 531/1639 | Batch Recon Mean = 441.2370
#   Batch 532/1639 | Batch Recon Mean = 578.7219
#   Batch 533/1639 | Batch Recon Mean = 714.4536
#   Batch 534/1639 | Batch Recon Mean = 322.6413
#   Batch 535/1639 | Batch Recon Mean = 293.0507
#   Batch 536/1639 | Batch Recon Mean = 1028.0856
#   Batch 537/1639 | Batch Recon Mean = 335.5433
#   Batch 538/1639 | Batch Recon Mean = 367.2312
#   Batch 539/1639 | Batch Recon Mean = 2963.5859
#   Batch 540/1639 | Batch Recon Mean = 517.8414
#   Batch 541/1639 | Batch Recon Mean = 418.2713
#   Batch 542/1639 | Batch Recon Mean = 1582.0527
#   Batch 543/1639 | Batch Recon Mean = 371.0179
#   Batch 544/1639 | Batch Recon Mean = 368.1205
#   Batch 545/1639 | Batch Recon Mean = 335.3452
#   Batch 546/1639 | Batch Recon Mean = 710.2170
#   Batch 547/1639 | Batch Recon Mean = 336.8161
#   Batch 548/1639 | Batch Recon Mean = 362.0901
#   Batch 549/1639 | Batch Recon Mean = 3283.3618
#   Batch 550/1639 | Batch Recon Mean = 432.2003
#   Batch 551/1639 | Batch Recon Mean = 20524.9727
#   Batch 552/1639 | Batch Recon Mean = 398.4619
#   Batch 553/1639 | Batch Recon Mean = 2180.5645
#   Batch 554/1639 | Batch Recon Mean = 470.2731
#   Batch 555/1639 | Batch Recon Mean = 385.5822
#   Batch 556/1639 | Batch Recon Mean = 527.0045
#   Batch 557/1639 | Batch Recon Mean = 599.4136
#   Batch 558/1639 | Batch Recon Mean = 3602.5874
#   Batch 559/1639 | Batch Recon Mean = 527.0150
#   Batch 560/1639 | Batch Recon Mean = 545.4293
#   Batch 561/1639 | Batch Recon Mean = 623.9503
#   Batch 562/1639 | Batch Recon Mean = 10664.0176
#   Batch 563/1639 | Batch Recon Mean = 502.0687
#   Batch 564/1639 | Batch Recon Mean = 413.9257
#   Batch 565/1639 | Batch Recon Mean = 1330.4279
#   Batch 566/1639 | Batch Recon Mean = 620.4268
#   Batch 567/1639 | Batch Recon Mean = 446.3825
#   Batch 568/1639 | Batch Recon Mean = 496.4494
#   Batch 569/1639 | Batch Recon Mean = 405.3990
#   Batch 570/1639 | Batch Recon Mean = 396.8000
#   Batch 571/1639 | Batch Recon Mean = 450.5779
#   Batch 572/1639 | Batch Recon Mean = 438.6127
#   Batch 573/1639 | Batch Recon Mean = 422.1092
#   Batch 574/1639 | Batch Recon Mean = 545.0054
#   Batch 575/1639 | Batch Recon Mean = 378.0181
#   Batch 576/1639 | Batch Recon Mean = 355.8510
#   Batch 577/1639 | Batch Recon Mean = 22559.1816
#   Batch 578/1639 | Batch Recon Mean = 332.0024
#   Batch 579/1639 | Batch Recon Mean = 342.7902
#   Batch 580/1639 | Batch Recon Mean = 2371.3513
#   Batch 581/1639 | Batch Recon Mean = 419.2785
#   Batch 582/1639 | Batch Recon Mean = 417.6272
#   Batch 583/1639 | Batch Recon Mean = 368.4389
#   Batch 584/1639 | Batch Recon Mean = 422.5091
#   Batch 585/1639 | Batch Recon Mean = 897.4848
#   Batch 586/1639 | Batch Recon Mean = 1151.9675
#   Batch 587/1639 | Batch Recon Mean = 452.9311
#   Batch 588/1639 | Batch Recon Mean = 517.1610
#   Batch 589/1639 | Batch Recon Mean = 448.8904
#   Batch 590/1639 | Batch Recon Mean = 1202.2872
#   Batch 591/1639 | Batch Recon Mean = 1387.4106
#   Batch 592/1639 | Batch Recon Mean = 425.3442
#   Batch 593/1639 | Batch Recon Mean = 529.1849
#   Batch 594/1639 | Batch Recon Mean = 1686.6902
#   Batch 595/1639 | Batch Recon Mean = 397.9696
#   Batch 596/1639 | Batch Recon Mean = 1006.4762
#   Batch 597/1639 | Batch Recon Mean = 278.3925
#   Batch 598/1639 | Batch Recon Mean = 467.2311
#   Batch 599/1639 | Batch Recon Mean = 487.4316
#   Batch 600/1639 | Batch Recon Mean = 1056115.5000
#   Batch 601/1639 | Batch Recon Mean = 369.4385
#   Batch 602/1639 | Batch Recon Mean = 428.8174
#   Batch 603/1639 | Batch Recon Mean = 615.8875
#   Batch 604/1639 | Batch Recon Mean = 808.6152
#   Batch 605/1639 | Batch Recon Mean = 597.2565
#   Batch 606/1639 | Batch Recon Mean = 433.9614
#   Batch 607/1639 | Batch Recon Mean = 1354.4144
#   Batch 608/1639 | Batch Recon Mean = 1043.5453
#   Batch 609/1639 | Batch Recon Mean = 467.6319
#   Batch 610/1639 | Batch Recon Mean = 739.7933
#   Batch 611/1639 | Batch Recon Mean = 348.8971
#   Batch 612/1639 | Batch Recon Mean = 642.3865
#   Batch 613/1639 | Batch Recon Mean = 921.5968
#   Batch 614/1639 | Batch Recon Mean = 544.7863
#   Batch 615/1639 | Batch Recon Mean = 617.9387
#   Batch 616/1639 | Batch Recon Mean = 392.0561
#   Batch 617/1639 | Batch Recon Mean = 522.0679
#   Batch 618/1639 | Batch Recon Mean = 431.0756
#   Batch 619/1639 | Batch Recon Mean = 659.9120
#   Batch 620/1639 | Batch Recon Mean = 396.8871
#   Batch 621/1639 | Batch Recon Mean = 394.4803
#   Batch 622/1639 | Batch Recon Mean = 4909.3394
#   Batch 623/1639 | Batch Recon Mean = 6205.4619
#   Batch 624/1639 | Batch Recon Mean = 352.3218
#   Batch 625/1639 | Batch Recon Mean = 376.9366
#   Batch 626/1639 | Batch Recon Mean = 1222.3726
#   Batch 627/1639 | Batch Recon Mean = 305.4504
#   Batch 628/1639 | Batch Recon Mean = 539.9421
#   Batch 629/1639 | Batch Recon Mean = 365.5411
#   Batch 630/1639 | Batch Recon Mean = 439.1593
#   Batch 631/1639 | Batch Recon Mean = 1871.8524
#   Batch 632/1639 | Batch Recon Mean = 457.5872
#   Batch 633/1639 | Batch Recon Mean = 327.9374
#   Batch 634/1639 | Batch Recon Mean = 466.0433
#   Batch 635/1639 | Batch Recon Mean = 971.2928
#   Batch 636/1639 | Batch Recon Mean = 464.9757
#   Batch 637/1639 | Batch Recon Mean = 574.8829
#   Batch 638/1639 | Batch Recon Mean = 732.5135
#   Batch 639/1639 | Batch Recon Mean = 357.4946
#   Batch 640/1639 | Batch Recon Mean = 512.6268
#   Batch 641/1639 | Batch Recon Mean = 522.8133
#   Batch 642/1639 | Batch Recon Mean = 969.2991
#   Batch 643/1639 | Batch Recon Mean = 453.3822
#   Batch 644/1639 | Batch Recon Mean = 430.4913
#   Batch 645/1639 | Batch Recon Mean = 501.0124
#   Batch 646/1639 | Batch Recon Mean = 315.9433
#   Batch 647/1639 | Batch Recon Mean = 562.2167
#   Batch 648/1639 | Batch Recon Mean = 459.1271
#   Batch 649/1639 | Batch Recon Mean = 491.4058
#   Batch 650/1639 | Batch Recon Mean = 709.0219
#   Batch 651/1639 | Batch Recon Mean = 363.2697
#   Batch 652/1639 | Batch Recon Mean = 898.2865
#   Batch 653/1639 | Batch Recon Mean = 553.0828
#   Batch 654/1639 | Batch Recon Mean = 1473.9703
#   Batch 655/1639 | Batch Recon Mean = 445.4428
#   Batch 656/1639 | Batch Recon Mean = 384.8240
#   Batch 657/1639 | Batch Recon Mean = 306.4386
#   Batch 658/1639 | Batch Recon Mean = 325.1633
#   Batch 659/1639 | Batch Recon Mean = 516.3762
#   Batch 660/1639 | Batch Recon Mean = 548.4093
#   Batch 661/1639 | Batch Recon Mean = 376.8828
#   Batch 662/1639 | Batch Recon Mean = 572.4496
#   Batch 663/1639 | Batch Recon Mean = 467.8405
#   Batch 664/1639 | Batch Recon Mean = 555.8613
#   Batch 665/1639 | Batch Recon Mean = 1456.2841
#   Batch 666/1639 | Batch Recon Mean = 337.0366
#   Batch 667/1639 | Batch Recon Mean = 4223.4702
#   Batch 668/1639 | Batch Recon Mean = 874.9435
#   Batch 669/1639 | Batch Recon Mean = 853.4431
#   Batch 670/1639 | Batch Recon Mean = 497.2037
#   Batch 671/1639 | Batch Recon Mean = 367.5042
#   Batch 672/1639 | Batch Recon Mean = 612.9702
#   Batch 673/1639 | Batch Recon Mean = 346.3252
#   Batch 674/1639 | Batch Recon Mean = 603.9801
#   Batch 675/1639 | Batch Recon Mean = 413.7842
#   Batch 676/1639 | Batch Recon Mean = 373.1450
#   Batch 677/1639 | Batch Recon Mean = 405.2697
#   Batch 678/1639 | Batch Recon Mean = 412.8569
#   Batch 679/1639 | Batch Recon Mean = 392.0672
#   Batch 680/1639 | Batch Recon Mean = 424.7246
#   Batch 681/1639 | Batch Recon Mean = 2052.6313
#   Batch 682/1639 | Batch Recon Mean = 1362.7168
#   Batch 683/1639 | Batch Recon Mean = 510.7413
#   Batch 684/1639 | Batch Recon Mean = 412.6287
#   Batch 685/1639 | Batch Recon Mean = 34642.5898
#   Batch 686/1639 | Batch Recon Mean = 437.9350
#   Batch 687/1639 | Batch Recon Mean = 401.8090
#   Batch 688/1639 | Batch Recon Mean = 865.0568
#   Batch 689/1639 | Batch Recon Mean = 581.7726
#   Batch 690/1639 | Batch Recon Mean = 310.3240
#   Batch 691/1639 | Batch Recon Mean = 698.9481
#   Batch 692/1639 | Batch Recon Mean = 447.2189
#   Batch 693/1639 | Batch Recon Mean = 376.2841
#   Batch 694/1639 | Batch Recon Mean = 448.6081
#   Batch 695/1639 | Batch Recon Mean = 711.4768
#   Batch 696/1639 | Batch Recon Mean = 474.1142
#   Batch 697/1639 | Batch Recon Mean = 1421.3073
#   Batch 698/1639 | Batch Recon Mean = 390.5538
#   Batch 699/1639 | Batch Recon Mean = 369.1439
#   Batch 700/1639 | Batch Recon Mean = 33874.7891
#   Batch 701/1639 | Batch Recon Mean = 335.5198
#   Batch 702/1639 | Batch Recon Mean = 472.9913
#   Batch 703/1639 | Batch Recon Mean = 584.7267
#   Batch 704/1639 | Batch Recon Mean = 401.2547
#   Batch 705/1639 | Batch Recon Mean = 467.7850
#   Batch 706/1639 | Batch Recon Mean = 746.7012
#   Batch 707/1639 | Batch Recon Mean = 362.9362
#   Batch 708/1639 | Batch Recon Mean = 399.4422
#   Batch 709/1639 | Batch Recon Mean = 698.5510
#   Batch 710/1639 | Batch Recon Mean = 454.6600
#   Batch 711/1639 | Batch Recon Mean = 277.1654
#   Batch 712/1639 | Batch Recon Mean = 849.9171
#   Batch 713/1639 | Batch Recon Mean = 311.0442
#   Batch 714/1639 | Batch Recon Mean = 8433.1689
#   Batch 715/1639 | Batch Recon Mean = 1968.2212
#   Batch 716/1639 | Batch Recon Mean = 10773.4336
#   Batch 717/1639 | Batch Recon Mean = 618.2251
#   Batch 718/1639 | Batch Recon Mean = 529.3696
#   Batch 719/1639 | Batch Recon Mean = 341.7917
#   Batch 720/1639 | Batch Recon Mean = 514.2551
#   Batch 721/1639 | Batch Recon Mean = 349.9246
#   Batch 722/1639 | Batch Recon Mean = 345.3141
#   Batch 723/1639 | Batch Recon Mean = 426.2224
#   Batch 724/1639 | Batch Recon Mean = 618.6967
#   Batch 725/1639 | Batch Recon Mean = 481.8152
#   Batch 726/1639 | Batch Recon Mean = 4204.5757
#   Batch 727/1639 | Batch Recon Mean = 451.0499
#   Batch 728/1639 | Batch Recon Mean = 154722.6719
#   Batch 729/1639 | Batch Recon Mean = 537.2378
#   Batch 730/1639 | Batch Recon Mean = 346.4753
#   Batch 731/1639 | Batch Recon Mean = 381.7106
#   Batch 732/1639 | Batch Recon Mean = 708.3207
#   Batch 733/1639 | Batch Recon Mean = 321.7596
#   Batch 734/1639 | Batch Recon Mean = 429.9147
#   Batch 735/1639 | Batch Recon Mean = 6883.7344
#   Batch 736/1639 | Batch Recon Mean = 421.9449
#   Batch 737/1639 | Batch Recon Mean = 323.5034
#   Batch 738/1639 | Batch Recon Mean = 844.2310
#   Batch 739/1639 | Batch Recon Mean = 405.0971
#   Batch 740/1639 | Batch Recon Mean = 58816.3633
#   Batch 741/1639 | Batch Recon Mean = 703.2000
#   Batch 742/1639 | Batch Recon Mean = 1597.1265
#   Batch 743/1639 | Batch Recon Mean = 430.4471
#   Batch 744/1639 | Batch Recon Mean = 664.8519
#   Batch 745/1639 | Batch Recon Mean = 423.3377
#   Batch 746/1639 | Batch Recon Mean = 437.7170
#   Batch 747/1639 | Batch Recon Mean = 755.4004
#   Batch 748/1639 | Batch Recon Mean = 1304.1776
#   Batch 749/1639 | Batch Recon Mean = 685.2764
#   Batch 750/1639 | Batch Recon Mean = 322.9237
#   Batch 751/1639 | Batch Recon Mean = 591.7725
#   Batch 752/1639 | Batch Recon Mean = 439.9507
#   Batch 753/1639 | Batch Recon Mean = 2789.6006
#   Batch 754/1639 | Batch Recon Mean = 501.8299
#   Batch 755/1639 | Batch Recon Mean = 312.4280
#   Batch 756/1639 | Batch Recon Mean = 123748.0781
#   Batch 757/1639 | Batch Recon Mean = 610.9337
#   Batch 758/1639 | Batch Recon Mean = 324.4977
#   Batch 759/1639 | Batch Recon Mean = 1947.1165
#   Batch 760/1639 | Batch Recon Mean = 481.8939
#   Batch 761/1639 | Batch Recon Mean = 1143.3744
#   Batch 762/1639 | Batch Recon Mean = 510.5215
#   Batch 763/1639 | Batch Recon Mean = 366.3842
#   Batch 764/1639 | Batch Recon Mean = 605.5098
#   Batch 765/1639 | Batch Recon Mean = 49277.8320
#   Batch 766/1639 | Batch Recon Mean = 1062.3335
#   Batch 767/1639 | Batch Recon Mean = 519.2295
#   Batch 768/1639 | Batch Recon Mean = 382.1401
#   Batch 769/1639 | Batch Recon Mean = 432.7313
#   Batch 770/1639 | Batch Recon Mean = 7227.9673
#   Batch 771/1639 | Batch Recon Mean = 934.8303
#   Batch 772/1639 | Batch Recon Mean = 362.6234
#   Batch 773/1639 | Batch Recon Mean = 441.3499
#   Batch 774/1639 | Batch Recon Mean = 513.2743
#   Batch 775/1639 | Batch Recon Mean = 996.2269
#   Batch 776/1639 | Batch Recon Mean = 635.4789
#   Batch 777/1639 | Batch Recon Mean = 401.3309
#   Batch 778/1639 | Batch Recon Mean = 387.4547
#   Batch 779/1639 | Batch Recon Mean = 384.2917
#   Batch 780/1639 | Batch Recon Mean = 465.8219
#   Batch 781/1639 | Batch Recon Mean = 126571.7891
#   Batch 782/1639 | Batch Recon Mean = 753.9434
#   Batch 783/1639 | Batch Recon Mean = 445.3455
#   Batch 784/1639 | Batch Recon Mean = 971.0809
#   Batch 785/1639 | Batch Recon Mean = 555.5289
#   Batch 786/1639 | Batch Recon Mean = 931.0258
#   Batch 787/1639 | Batch Recon Mean = 513.3007
#   Batch 788/1639 | Batch Recon Mean = 1687.3037
#   Batch 789/1639 | Batch Recon Mean = 264.1547
#   Batch 790/1639 | Batch Recon Mean = 510.2661
#   Batch 791/1639 | Batch Recon Mean = 474.3730
#   Batch 792/1639 | Batch Recon Mean = 375.9526
#   Batch 793/1639 | Batch Recon Mean = 354.6714
#   Batch 794/1639 | Batch Recon Mean = 399.5410
#   Batch 795/1639 | Batch Recon Mean = 967.6755
#   Batch 796/1639 | Batch Recon Mean = 356.1297
#   Batch 797/1639 | Batch Recon Mean = 441.7931
#   Batch 798/1639 | Batch Recon Mean = 11465.6797
#   Batch 799/1639 | Batch Recon Mean = 535.5115
#   Batch 800/1639 | Batch Recon Mean = 419.8733
#   Batch 801/1639 | Batch Recon Mean = 340.2130
#   Batch 802/1639 | Batch Recon Mean = 346.9521
#   Batch 803/1639 | Batch Recon Mean = 384.2855
#   Batch 804/1639 | Batch Recon Mean = 366.4971
#   Batch 805/1639 | Batch Recon Mean = 330.0558
#   Batch 806/1639 | Batch Recon Mean = 2990.9346
#   Batch 807/1639 | Batch Recon Mean = 515.3903
#   Batch 808/1639 | Batch Recon Mean = 3395.7114
#   Batch 809/1639 | Batch Recon Mean = 709.1870
#   Batch 810/1639 | Batch Recon Mean = 415.5905
#   Batch 811/1639 | Batch Recon Mean = 550.7928
#   Batch 812/1639 | Batch Recon Mean = 905.4178
#   Batch 813/1639 | Batch Recon Mean = 363.7128
#   Batch 814/1639 | Batch Recon Mean = 579.5721
#   Batch 815/1639 | Batch Recon Mean = 367.1797
#   Batch 816/1639 | Batch Recon Mean = 963.0560
#   Batch 817/1639 | Batch Recon Mean = 448.2186
#   Batch 818/1639 | Batch Recon Mean = 520.4870
#   Batch 819/1639 | Batch Recon Mean = 418.5817
#   Batch 820/1639 | Batch Recon Mean = 499.9493
#   Batch 821/1639 | Batch Recon Mean = 470.7182
#   Batch 822/1639 | Batch Recon Mean = 365.3642
#   Batch 823/1639 | Batch Recon Mean = 409.1934
#   Batch 824/1639 | Batch Recon Mean = 502.3674
#   Batch 825/1639 | Batch Recon Mean = 445.9314
#   Batch 826/1639 | Batch Recon Mean = 499.5528
#   Batch 827/1639 | Batch Recon Mean = 452.7414
#   Batch 828/1639 | Batch Recon Mean = 474.2812
#   Batch 829/1639 | Batch Recon Mean = 436.2890
#   Batch 830/1639 | Batch Recon Mean = 394.3433
#   Batch 831/1639 | Batch Recon Mean = 606.1627
#   Batch 832/1639 | Batch Recon Mean = 454.5139
#   Batch 833/1639 | Batch Recon Mean = 445.8496
#   Batch 834/1639 | Batch Recon Mean = 350.5640
#   Batch 835/1639 | Batch Recon Mean = 389.0025
#   Batch 836/1639 | Batch Recon Mean = 543.7013
#   Batch 837/1639 | Batch Recon Mean = 363.6602
#   Batch 838/1639 | Batch Recon Mean = 22912.3691
#   Batch 839/1639 | Batch Recon Mean = 607.4343
#   Batch 840/1639 | Batch Recon Mean = 569.1500
#   Batch 841/1639 | Batch Recon Mean = 2059.7080
#   Batch 842/1639 | Batch Recon Mean = 8730.1738
#   Batch 843/1639 | Batch Recon Mean = 503.1559
#   Batch 844/1639 | Batch Recon Mean = 633.9711
#   Batch 845/1639 | Batch Recon Mean = 484.1166
#   Batch 846/1639 | Batch Recon Mean = 350.5714
#   Batch 847/1639 | Batch Recon Mean = 2289.7095
#   Batch 848/1639 | Batch Recon Mean = 434.7591
#   Batch 849/1639 | Batch Recon Mean = 507.6905
#   Batch 850/1639 | Batch Recon Mean = 372.3290
#   Batch 851/1639 | Batch Recon Mean = 758.4644
#   Batch 852/1639 | Batch Recon Mean = 376.3247
#   Batch 853/1639 | Batch Recon Mean = 317.0759
#   Batch 854/1639 | Batch Recon Mean = 3261.1548
#   Batch 855/1639 | Batch Recon Mean = 568.8923
#   Batch 856/1639 | Batch Recon Mean = 591.6832
#   Batch 857/1639 | Batch Recon Mean = 810.0400
#   Batch 858/1639 | Batch Recon Mean = 440.0566
#   Batch 859/1639 | Batch Recon Mean = 551.2402
#   Batch 860/1639 | Batch Recon Mean = 173054.0156
#   Batch 861/1639 | Batch Recon Mean = 469.4795
#   Batch 862/1639 | Batch Recon Mean = 1784.9335
#   Batch 863/1639 | Batch Recon Mean = 482.5255
#   Batch 864/1639 | Batch Recon Mean = 7984.4531
#   Batch 865/1639 | Batch Recon Mean = 1990.6379
#   Batch 866/1639 | Batch Recon Mean = 621.6718
#   Batch 867/1639 | Batch Recon Mean = 905.0099
#   Batch 868/1639 | Batch Recon Mean = 2868.5513
#   Batch 869/1639 | Batch Recon Mean = 355.4362
#   Batch 870/1639 | Batch Recon Mean = 526.1861
#   Batch 871/1639 | Batch Recon Mean = 430.3081
#   Batch 872/1639 | Batch Recon Mean = 338.4937
#   Batch 873/1639 | Batch Recon Mean = 398.3476
#   Batch 874/1639 | Batch Recon Mean = 507.7195
#   Batch 875/1639 | Batch Recon Mean = 10876.7168
#   Batch 876/1639 | Batch Recon Mean = 839.2104
#   Batch 877/1639 | Batch Recon Mean = 30564.9863
#   Batch 878/1639 | Batch Recon Mean = 735.6981
#   Batch 879/1639 | Batch Recon Mean = 705.9701
#   Batch 880/1639 | Batch Recon Mean = 376.0781
#   Batch 881/1639 | Batch Recon Mean = 447.4050
#   Batch 882/1639 | Batch Recon Mean = 453.0828
#   Batch 883/1639 | Batch Recon Mean = 328.3845
#   Batch 884/1639 | Batch Recon Mean = 476.0820
#   Batch 885/1639 | Batch Recon Mean = 387.3180
#   Batch 886/1639 | Batch Recon Mean = 497.6929
#   Batch 887/1639 | Batch Recon Mean = 289236.3125
#   Batch 888/1639 | Batch Recon Mean = 418.6851
#   Batch 889/1639 | Batch Recon Mean = 776.3227
#   Batch 890/1639 | Batch Recon Mean = 441.5199
#   Batch 891/1639 | Batch Recon Mean = 572.5190
#   Batch 892/1639 | Batch Recon Mean = 396.8174
#   Batch 893/1639 | Batch Recon Mean = 2534.1206
#   Batch 894/1639 | Batch Recon Mean = 511.8517
#   Batch 895/1639 | Batch Recon Mean = 604.8967
#   Batch 896/1639 | Batch Recon Mean = 498.2481
#   Batch 897/1639 | Batch Recon Mean = 389.2341
#   Batch 898/1639 | Batch Recon Mean = 550.5028
#   Batch 899/1639 | Batch Recon Mean = 625.3705
#   Batch 900/1639 | Batch Recon Mean = 361.3957
#   Batch 901/1639 | Batch Recon Mean = 2642.1714
#   Batch 902/1639 | Batch Recon Mean = 377.2639
#   Batch 903/1639 | Batch Recon Mean = 560.3573
#   Batch 904/1639 | Batch Recon Mean = 375.8541
#   Batch 905/1639 | Batch Recon Mean = 450.6421
#   Batch 906/1639 | Batch Recon Mean = 446.0648
#   Batch 907/1639 | Batch Recon Mean = 486.0498
#   Batch 908/1639 | Batch Recon Mean = 455.6024
#   Batch 909/1639 | Batch Recon Mean = 656.0514
#   Batch 910/1639 | Batch Recon Mean = 399.4932
#   Batch 911/1639 | Batch Recon Mean = 420.8388
#   Batch 912/1639 | Batch Recon Mean = 422.7047
#   Batch 913/1639 | Batch Recon Mean = 408.8149
#   Batch 914/1639 | Batch Recon Mean = 353.6466
#   Batch 915/1639 | Batch Recon Mean = 871.1725
#   Batch 916/1639 | Batch Recon Mean = 805.0803
#   Batch 917/1639 | Batch Recon Mean = 455.6738
#   Batch 918/1639 | Batch Recon Mean = 1415.4590
#   Batch 919/1639 | Batch Recon Mean = 3559.8743
#   Batch 920/1639 | Batch Recon Mean = 459.1413
#   Batch 921/1639 | Batch Recon Mean = 420.0877
#   Batch 922/1639 | Batch Recon Mean = 573.9811
#   Batch 923/1639 | Batch Recon Mean = 469.9136
#   Batch 924/1639 | Batch Recon Mean = 438.1890
#   Batch 925/1639 | Batch Recon Mean = 446.8139
#   Batch 926/1639 | Batch Recon Mean = 11760.1709
#   Batch 927/1639 | Batch Recon Mean = 2438.6631
#   Batch 928/1639 | Batch Recon Mean = 15375.9463
#   Batch 929/1639 | Batch Recon Mean = 1469.2285
#   Batch 930/1639 | Batch Recon Mean = 426.2805
#   Batch 931/1639 | Batch Recon Mean = 394.1310
#   Batch 932/1639 | Batch Recon Mean = 1387.7754
#   Batch 933/1639 | Batch Recon Mean = 337.4909
#   Batch 934/1639 | Batch Recon Mean = 1878.4204
#   Batch 935/1639 | Batch Recon Mean = 564.7355
#   Batch 936/1639 | Batch Recon Mean = 544.5177
#   Batch 937/1639 | Batch Recon Mean = 362.3424
#   Batch 938/1639 | Batch Recon Mean = 1585.1440
#   Batch 939/1639 | Batch Recon Mean = 434.1760
#   Batch 940/1639 | Batch Recon Mean = 449.4405
#   Batch 941/1639 | Batch Recon Mean = 624.6187
#   Batch 942/1639 | Batch Recon Mean = 292.5972
#   Batch 943/1639 | Batch Recon Mean = 484.2510
#   Batch 944/1639 | Batch Recon Mean = 449.2794
#   Batch 945/1639 | Batch Recon Mean = 523.0374
#   Batch 946/1639 | Batch Recon Mean = 1862.0508
#   Batch 947/1639 | Batch Recon Mean = 1119.7576
#   Batch 948/1639 | Batch Recon Mean = 513.9413
#   Batch 949/1639 | Batch Recon Mean = 492.3785
#   Batch 950/1639 | Batch Recon Mean = 365.4561
#   Batch 951/1639 | Batch Recon Mean = 838.1632
#   Batch 952/1639 | Batch Recon Mean = 346.2696
#   Batch 953/1639 | Batch Recon Mean = 370.9846
#   Batch 954/1639 | Batch Recon Mean = 294.0085
#   Batch 955/1639 | Batch Recon Mean = 381.5766
#   Batch 956/1639 | Batch Recon Mean = 341.9711
#   Batch 957/1639 | Batch Recon Mean = 345.2173
#   Batch 958/1639 | Batch Recon Mean = 439.2852
#   Batch 959/1639 | Batch Recon Mean = 363.4104
#   Batch 960/1639 | Batch Recon Mean = 343.7037
#   Batch 961/1639 | Batch Recon Mean = 508.9592
#   Batch 962/1639 | Batch Recon Mean = 329.1115
#   Batch 963/1639 | Batch Recon Mean = 553.9521
#   Batch 964/1639 | Batch Recon Mean = 374.3977
#   Batch 965/1639 | Batch Recon Mean = 487.1310
#   Batch 966/1639 | Batch Recon Mean = 301.0948
#   Batch 967/1639 | Batch Recon Mean = 553.5728
#   Batch 968/1639 | Batch Recon Mean = 290.6104
#   Batch 969/1639 | Batch Recon Mean = 930.7832
#   Batch 970/1639 | Batch Recon Mean = 445.3952
#   Batch 971/1639 | Batch Recon Mean = 719.5978
#   Batch 972/1639 | Batch Recon Mean = 376.7598
#   Batch 973/1639 | Batch Recon Mean = 1052.0393
#   Batch 974/1639 | Batch Recon Mean = 476.6131
#   Batch 975/1639 | Batch Recon Mean = 544.6432
#   Batch 976/1639 | Batch Recon Mean = 480.5027
#   Batch 977/1639 | Batch Recon Mean = 371.1322
#   Batch 978/1639 | Batch Recon Mean = 475.5734
#   Batch 979/1639 | Batch Recon Mean = 394.8079
#   Batch 980/1639 | Batch Recon Mean = 416.8327
#   Batch 981/1639 | Batch Recon Mean = 818.1179
#   Batch 982/1639 | Batch Recon Mean = 453.3719
#   Batch 983/1639 | Batch Recon Mean = 464.4177
#   Batch 984/1639 | Batch Recon Mean = 330.4777
#   Batch 985/1639 | Batch Recon Mean = 450.6431
#   Batch 986/1639 | Batch Recon Mean = 483.3043
#   Batch 987/1639 | Batch Recon Mean = 892.8785
#   Batch 988/1639 | Batch Recon Mean = 387415.8750
#   Batch 989/1639 | Batch Recon Mean = 1208.6537
#   Batch 990/1639 | Batch Recon Mean = 398.5847
#   Batch 991/1639 | Batch Recon Mean = 820.9896
#   Batch 992/1639 | Batch Recon Mean = 698.6578
#   Batch 993/1639 | Batch Recon Mean = 404.9630
#   Batch 994/1639 | Batch Recon Mean = 358.8867
#   Batch 995/1639 | Batch Recon Mean = 325.7773
#   Batch 996/1639 | Batch Recon Mean = 521.6849
#   Batch 997/1639 | Batch Recon Mean = 532.3622
#   Batch 998/1639 | Batch Recon Mean = 386.0435
#   Batch 999/1639 | Batch Recon Mean = 388.0797
#   Batch 1000/1639 | Batch Recon Mean = 440.8260
#   Batch 1001/1639 | Batch Recon Mean = 607.0477
#   Batch 1002/1639 | Batch Recon Mean = 392.8748
#   Batch 1003/1639 | Batch Recon Mean = 1530.3776
#   Batch 1004/1639 | Batch Recon Mean = 418.8369
#   Batch 1005/1639 | Batch Recon Mean = 1631.0450
#   Batch 1006/1639 | Batch Recon Mean = 500.8174
#   Batch 1007/1639 | Batch Recon Mean = 25034.2305
#   Batch 1008/1639 | Batch Recon Mean = 297.5606
#   Batch 1009/1639 | Batch Recon Mean = 625.2678
#   Batch 1010/1639 | Batch Recon Mean = 1167.9431
#   Batch 1011/1639 | Batch Recon Mean = 2132.5037
#   Batch 1012/1639 | Batch Recon Mean = 366.6176
#   Batch 1013/1639 | Batch Recon Mean = 431.9202
#   Batch 1014/1639 | Batch Recon Mean = 397.8918
#   Batch 1015/1639 | Batch Recon Mean = 436.2878
#   Batch 1016/1639 | Batch Recon Mean = 403.6539
#   Batch 1017/1639 | Batch Recon Mean = 431.9242
# ...
#   Batch 1310/1639 | Batch Recon Mean = 331.0869
#   Batch 1311/1639 | Batch Recon Mean = 494.5217
#   Batch 1312/1639 | Batch Recon Mean = 653.2797
#   Batch 1313/1639 | Batch Recon Mean = 393.2707
#   Batch 1314/1639 | Batch Recon Mean = 604.3394
#   Batch 1315/1639 | Batch Recon Mean = 388.9799
#   Batch 1316/1639 | Batch Recon Mean = 996.8984
#   Batch 1317/1639 | Batch Recon Mean = 407.6152
#   Batch 1318/1639 | Batch Recon Mean = 1251.2202
#   Batch 1319/1639 | Batch Recon Mean = 548.1065
#   Batch 1320/1639 | Batch Recon Mean = 407.6620
#   Batch 1321/1639 | Batch Recon Mean = 3338.9355
#   Batch 1322/1639 | Batch Recon Mean = 523.5605
#   Batch 1323/1639 | Batch Recon Mean = 689.5497
#   Batch 1324/1639 | Batch Recon Mean = 8640.3350
#   Batch 1325/1639 | Batch Recon Mean = 426.7704
#   Batch 1326/1639 | Batch Recon Mean = 5946.7339
#   Batch 1327/1639 | Batch Recon Mean = 552.9762
#   Batch 1328/1639 | Batch Recon Mean = 781.4725
#   Batch 1329/1639 | Batch Recon Mean = 1862.3040
#   Batch 1330/1639 | Batch Recon Mean = 403.5578
#   Batch 1331/1639 | Batch Recon Mean = 576.1456
#   Batch 1332/1639 | Batch Recon Mean = 302.8560
#   Batch 1333/1639 | Batch Recon Mean = 534.4569
#   Batch 1334/1639 | Batch Recon Mean = 996.8762
#   Batch 1335/1639 | Batch Recon Mean = 464.1750
#   Batch 1336/1639 | Batch Recon Mean = 356.6475
#   Batch 1337/1639 | Batch Recon Mean = 394.7946
#   Batch 1338/1639 | Batch Recon Mean = 481739.4688
#   Batch 1339/1639 | Batch Recon Mean = 885.2374
#   Batch 1340/1639 | Batch Recon Mean = 432.2329
#   Batch 1341/1639 | Batch Recon Mean = 486.9919
#   Batch 1342/1639 | Batch Recon Mean = 384.1284
#   Batch 1343/1639 | Batch Recon Mean = 307.7510
#   Batch 1344/1639 | Batch Recon Mean = 268.8095
#   Batch 1345/1639 | Batch Recon Mean = 520.3488
#   Batch 1346/1639 | Batch Recon Mean = 13821.4658
#   Batch 1347/1639 | Batch Recon Mean = 420.1802
#   Batch 1348/1639 | Batch Recon Mean = 332.4759
#   Batch 1349/1639 | Batch Recon Mean = 1206.2240
#   Batch 1350/1639 | Batch Recon Mean = 398.1046
#   Batch 1351/1639 | Batch Recon Mean = 584.5875
#   Batch 1352/1639 | Batch Recon Mean = 446.3581
#   Batch 1353/1639 | Batch Recon Mean = 420.5808
#   Batch 1354/1639 | Batch Recon Mean = 327558.5312
#   Batch 1355/1639 | Batch Recon Mean = 713.2261
#   Batch 1356/1639 | Batch Recon Mean = 110390.5078
#   Batch 1357/1639 | Batch Recon Mean = 530.0762
#   Batch 1358/1639 | Batch Recon Mean = 436.9329
#   Batch 1359/1639 | Batch Recon Mean = 523.7515
#   Batch 1360/1639 | Batch Recon Mean = 422.9657
#   Batch 1361/1639 | Batch Recon Mean = 4236.3965
#   Batch 1362/1639 | Batch Recon Mean = 1760.0250
#   Batch 1363/1639 | Batch Recon Mean = 456.2585
#   Batch 1364/1639 | Batch Recon Mean = 472.3333
#   Batch 1365/1639 | Batch Recon Mean = 5974.9731
#   Batch 1366/1639 | Batch Recon Mean = 786.4143
#   Batch 1367/1639 | Batch Recon Mean = 734.6538
#   Batch 1368/1639 | Batch Recon Mean = 519.5930
#   Batch 1369/1639 | Batch Recon Mean = 567.6579
#   Batch 1370/1639 | Batch Recon Mean = 343.5318
#   Batch 1371/1639 | Batch Recon Mean = 1848.4089
#   Batch 1372/1639 | Batch Recon Mean = 518.8563
#   Batch 1373/1639 | Batch Recon Mean = 563.5972
#   Batch 1374/1639 | Batch Recon Mean = 635.8530
#   Batch 1375/1639 | Batch Recon Mean = 423.0648
#   Batch 1376/1639 | Batch Recon Mean = 353.4443
#   Batch 1377/1639 | Batch Recon Mean = 497.0202
#   Batch 1378/1639 | Batch Recon Mean = 5614.4932
#   Batch 1379/1639 | Batch Recon Mean = 399.1573
#   Batch 1380/1639 | Batch Recon Mean = 13330.4902
#   Batch 1381/1639 | Batch Recon Mean = 493.2579
#   Batch 1382/1639 | Batch Recon Mean = 498.2011
#   Batch 1383/1639 | Batch Recon Mean = 596.7386
#   Batch 1384/1639 | Batch Recon Mean = 400.9131
#   Batch 1385/1639 | Batch Recon Mean = 67531.7266
#   Batch 1386/1639 | Batch Recon Mean = 351.0407
#   Batch 1387/1639 | Batch Recon Mean = 464.3829
#   Batch 1388/1639 | Batch Recon Mean = 421.5886
#   Batch 1389/1639 | Batch Recon Mean = 624.0768
#   Batch 1390/1639 | Batch Recon Mean = 454.0678
#   Batch 1391/1639 | Batch Recon Mean = 435.2130
#   Batch 1392/1639 | Batch Recon Mean = 370.6992
#   Batch 1393/1639 | Batch Recon Mean = 442.5689
#   Batch 1394/1639 | Batch Recon Mean = 1050892.7500
#   Batch 1395/1639 | Batch Recon Mean = 708.3741
#   Batch 1396/1639 | Batch Recon Mean = 561.8412
#   Batch 1397/1639 | Batch Recon Mean = 425.5982
#   Batch 1398/1639 | Batch Recon Mean = 604.9481
#   Batch 1399/1639 | Batch Recon Mean = 427.3987
#   Batch 1400/1639 | Batch Recon Mean = 686.5076
#   Batch 1401/1639 | Batch Recon Mean = 5934.4590
#   Batch 1402/1639 | Batch Recon Mean = 380.8824
#   Batch 1403/1639 | Batch Recon Mean = 2031.2845
#   Batch 1404/1639 | Batch Recon Mean = 389.6513
#   Batch 1405/1639 | Batch Recon Mean = 1496.2438
#   Batch 1406/1639 | Batch Recon Mean = 480.0426
#   Batch 1407/1639 | Batch Recon Mean = 2104.9585
#   Batch 1408/1639 | Batch Recon Mean = 573.4905
#   Batch 1409/1639 | Batch Recon Mean = 360.1638
#   Batch 1410/1639 | Batch Recon Mean = 347.4843
#   Batch 1411/1639 | Batch Recon Mean = 822.0733
#   Batch 1412/1639 | Batch Recon Mean = 406.0811
#   Batch 1413/1639 | Batch Recon Mean = 418.1494
#   Batch 1414/1639 | Batch Recon Mean = 282.3565
#   Batch 1415/1639 | Batch Recon Mean = 351.9343
#   Batch 1416/1639 | Batch Recon Mean = 404.6555
#   Batch 1417/1639 | Batch Recon Mean = 443715776.0000
#   Batch 1418/1639 | Batch Recon Mean = 298.3657
#   Batch 1419/1639 | Batch Recon Mean = 371.9504
#   Batch 1420/1639 | Batch Recon Mean = 579.7238
#   Batch 1421/1639 | Batch Recon Mean = 1672.9675
#   Batch 1422/1639 | Batch Recon Mean = 1367.8282
#   Batch 1423/1639 | Batch Recon Mean = 539.3217
#   Batch 1424/1639 | Batch Recon Mean = 12982.3281
#   Batch 1425/1639 | Batch Recon Mean = 434.3877
#   Batch 1426/1639 | Batch Recon Mean = 381.7603
#   Batch 1427/1639 | Batch Recon Mean = 453.1759
#   Batch 1428/1639 | Batch Recon Mean = 360.5246
#   Batch 1429/1639 | Batch Recon Mean = 610.9938
#   Batch 1430/1639 | Batch Recon Mean = 608.0006
#   Batch 1431/1639 | Batch Recon Mean = 446.1216
#   Batch 1432/1639 | Batch Recon Mean = 387.5077
#   Batch 1433/1639 | Batch Recon Mean = 413.3128
#   Batch 1434/1639 | Batch Recon Mean = 465.1365
#   Batch 1435/1639 | Batch Recon Mean = 19478.2852
#   Batch 1436/1639 | Batch Recon Mean = 1068.8022
#   Batch 1437/1639 | Batch Recon Mean = 417.9013
#   Batch 1438/1639 | Batch Recon Mean = 578.9423
#   Batch 1439/1639 | Batch Recon Mean = 350.6570
#   Batch 1440/1639 | Batch Recon Mean = 39367.4141
#   Batch 1441/1639 | Batch Recon Mean = 679.6265
#   Batch 1442/1639 | Batch Recon Mean = 397.2558
#   Batch 1443/1639 | Batch Recon Mean = 1797.0061
#   Batch 1444/1639 | Batch Recon Mean = 487.3526
#   Batch 1445/1639 | Batch Recon Mean = 317.4831
#   Batch 1446/1639 | Batch Recon Mean = 482.3451
#   Batch 1447/1639 | Batch Recon Mean = 694.0608
#   Batch 1448/1639 | Batch Recon Mean = 407.9296
#   Batch 1449/1639 | Batch Recon Mean = 583.3065
#   Batch 1450/1639 | Batch Recon Mean = 475.9875
#   Batch 1451/1639 | Batch Recon Mean = 693.6396
#   Batch 1452/1639 | Batch Recon Mean = 891.6984
#   Batch 1453/1639 | Batch Recon Mean = 403.4695
#   Batch 1454/1639 | Batch Recon Mean = 319.9910
#   Batch 1455/1639 | Batch Recon Mean = 346.6901
#   Batch 1456/1639 | Batch Recon Mean = 643.3154
#   Batch 1457/1639 | Batch Recon Mean = 709.6163
#   Batch 1458/1639 | Batch Recon Mean = 504.2379
#   Batch 1459/1639 | Batch Recon Mean = 452.3064
#   Batch 1460/1639 | Batch Recon Mean = 367.8025
#   Batch 1461/1639 | Batch Recon Mean = 395.6343
#   Batch 1462/1639 | Batch Recon Mean = 414.5881
#   Batch 1463/1639 | Batch Recon Mean = 455.9862
#   Batch 1464/1639 | Batch Recon Mean = 357.2433
#   Batch 1465/1639 | Batch Recon Mean = 1139.7009
#   Batch 1466/1639 | Batch Recon Mean = 323.4390
#   Batch 1467/1639 | Batch Recon Mean = 367.8623
#   Batch 1468/1639 | Batch Recon Mean = 513.7874
#   Batch 1469/1639 | Batch Recon Mean = 730.2029
#   Batch 1470/1639 | Batch Recon Mean = 342.1722
#   Batch 1471/1639 | Batch Recon Mean = 4425.8662
#   Batch 1472/1639 | Batch Recon Mean = 479.3406
#   Batch 1473/1639 | Batch Recon Mean = 507.9540
#   Batch 1474/1639 | Batch Recon Mean = 357.8586
#   Batch 1475/1639 | Batch Recon Mean = 417.9428
#   Batch 1476/1639 | Batch Recon Mean = 346.0545
#   Batch 1477/1639 | Batch Recon Mean = 462.2811
#   Batch 1478/1639 | Batch Recon Mean = 337.5875
#   Batch 1479/1639 | Batch Recon Mean = 498.7481
#   Batch 1480/1639 | Batch Recon Mean = 488.4029
#   Batch 1481/1639 | Batch Recon Mean = 596.4807
#   Batch 1482/1639 | Batch Recon Mean = 3472.5630
#   Batch 1483/1639 | Batch Recon Mean = 426.6711
#   Batch 1484/1639 | Batch Recon Mean = 672.4052
#   Batch 1485/1639 | Batch Recon Mean = 1096.5278
#   Batch 1486/1639 | Batch Recon Mean = 1135.2672
#   Batch 1487/1639 | Batch Recon Mean = 391.3986
#   Batch 1488/1639 | Batch Recon Mean = 4430028.0000
#   Batch 1489/1639 | Batch Recon Mean = 416.0401
#   Batch 1490/1639 | Batch Recon Mean = 351.9043
#   Batch 1491/1639 | Batch Recon Mean = 392.2315
#   Batch 1492/1639 | Batch Recon Mean = 342.7336
#   Batch 1493/1639 | Batch Recon Mean = 2129.9673
#   Batch 1494/1639 | Batch Recon Mean = 458.3403
#   Batch 1495/1639 | Batch Recon Mean = 382.3180
#   Batch 1496/1639 | Batch Recon Mean = 421.3735
#   Batch 1497/1639 | Batch Recon Mean = 459.5902
#   Batch 1498/1639 | Batch Recon Mean = 8813.4170
#   Batch 1499/1639 | Batch Recon Mean = 2718.0376
#   Batch 1500/1639 | Batch Recon Mean = 322.1891
#   Batch 1501/1639 | Batch Recon Mean = 478.6801
#   Batch 1502/1639 | Batch Recon Mean = 1112.2004
#   Batch 1503/1639 | Batch Recon Mean = 826.2800
#   Batch 1504/1639 | Batch Recon Mean = 985.0254
#   Batch 1505/1639 | Batch Recon Mean = 361.9073
#   Batch 1506/1639 | Batch Recon Mean = 450.7108
#   Batch 1507/1639 | Batch Recon Mean = 1249.1252
#   Batch 1508/1639 | Batch Recon Mean = 1394.2346
#   Batch 1509/1639 | Batch Recon Mean = 416.0194
#   Batch 1510/1639 | Batch Recon Mean = 462.4464
#   Batch 1511/1639 | Batch Recon Mean = 501.5492
#   Batch 1512/1639 | Batch Recon Mean = 572.3906
#   Batch 1513/1639 | Batch Recon Mean = 431.6106
#   Batch 1514/1639 | Batch Recon Mean = 959.2022
#   Batch 1515/1639 | Batch Recon Mean = 437.4879
#   Batch 1516/1639 | Batch Recon Mean = 636.8034
#   Batch 1517/1639 | Batch Recon Mean = 363.0394
#   Batch 1518/1639 | Batch Recon Mean = 534.1062
#   Batch 1519/1639 | Batch Recon Mean = 793.3098
#   Batch 1520/1639 | Batch Recon Mean = 369.0151
#   Batch 1521/1639 | Batch Recon Mean = 481.3655
#   Batch 1522/1639 | Batch Recon Mean = 384.4619
#   Batch 1523/1639 | Batch Recon Mean = 678.5842
#   Batch 1524/1639 | Batch Recon Mean = 829.9380
#   Batch 1525/1639 | Batch Recon Mean = 313.7884
#   Batch 1526/1639 | Batch Recon Mean = 338.1847
#   Batch 1527/1639 | Batch Recon Mean = 433.0479
#   Batch 1528/1639 | Batch Recon Mean = 524.7803
#   Batch 1529/1639 | Batch Recon Mean = 430.4126
#   Batch 1530/1639 | Batch Recon Mean = 1472.0887
#   Batch 1531/1639 | Batch Recon Mean = 1499.5222
#   Batch 1532/1639 | Batch Recon Mean = 1221.8694
#   Batch 1533/1639 | Batch Recon Mean = 499.5200
#   Batch 1534/1639 | Batch Recon Mean = 486.3786
#   Batch 1535/1639 | Batch Recon Mean = 1339.6858
#   Batch 1536/1639 | Batch Recon Mean = 513.4353
#   Batch 1537/1639 | Batch Recon Mean = 680.4325
#   Batch 1538/1639 | Batch Recon Mean = 389.6558
#   Batch 1539/1639 | Batch Recon Mean = 1254.5487
#   Batch 1540/1639 | Batch Recon Mean = 445.4169
#   Batch 1541/1639 | Batch Recon Mean = 594.9071
#   Batch 1542/1639 | Batch Recon Mean = 3986.2373
#   Batch 1543/1639 | Batch Recon Mean = 1453.6245
#   Batch 1544/1639 | Batch Recon Mean = 460.1513
#   Batch 1545/1639 | Batch Recon Mean = 433.0498
#   Batch 1546/1639 | Batch Recon Mean = 441.4620
#   Batch 1547/1639 | Batch Recon Mean = 529.3403
#   Batch 1548/1639 | Batch Recon Mean = 419.6006
#   Batch 1549/1639 | Batch Recon Mean = 398.5931
#   Batch 1550/1639 | Batch Recon Mean = 511.0648
#   Batch 1551/1639 | Batch Recon Mean = 363.9836
#   Batch 1552/1639 | Batch Recon Mean = 387.0896
#   Batch 1553/1639 | Batch Recon Mean = 428.5594
#   Batch 1554/1639 | Batch Recon Mean = 359.4823
#   Batch 1555/1639 | Batch Recon Mean = 540.1786
#   Batch 1556/1639 | Batch Recon Mean = 421.0872
#   Batch 1557/1639 | Batch Recon Mean = 984.0889
#   Batch 1558/1639 | Batch Recon Mean = 4701.9150
#   Batch 1559/1639 | Batch Recon Mean = 370.6690
#   Batch 1560/1639 | Batch Recon Mean = 647.8516
#   Batch 1561/1639 | Batch Recon Mean = 343.1639
#   Batch 1562/1639 | Batch Recon Mean = 261.9066
#   Batch 1563/1639 | Batch Recon Mean = 450.5856
#   Batch 1564/1639 | Batch Recon Mean = 433.8873
#   Batch 1565/1639 | Batch Recon Mean = 452.6321
#   Batch 1566/1639 | Batch Recon Mean = 352.6945
#   Batch 1567/1639 | Batch Recon Mean = 567.6595
#   Batch 1568/1639 | Batch Recon Mean = 569.6880
#   Batch 1569/1639 | Batch Recon Mean = 5256.2749
#   Batch 1570/1639 | Batch Recon Mean = 325.9248
#   Batch 1571/1639 | Batch Recon Mean = 354.0545
#   Batch 1572/1639 | Batch Recon Mean = 544.7477
#   Batch 1573/1639 | Batch Recon Mean = 604.2846
#   Batch 1574/1639 | Batch Recon Mean = 375.9000
#   Batch 1575/1639 | Batch Recon Mean = 423.5411
#   Batch 1576/1639 | Batch Recon Mean = 893.1288
#   Batch 1577/1639 | Batch Recon Mean = 3758.3555
#   Batch 1578/1639 | Batch Recon Mean = 6233.7573
#   Batch 1579/1639 | Batch Recon Mean = 523.7071
#   Batch 1580/1639 | Batch Recon Mean = 971.6141
#   Batch 1581/1639 | Batch Recon Mean = 405.5005
#   Batch 1582/1639 | Batch Recon Mean = 1128.7700
#   Batch 1583/1639 | Batch Recon Mean = 8123.5820
#   Batch 1584/1639 | Batch Recon Mean = 410.4974
#   Batch 1585/1639 | Batch Recon Mean = 461.3332
#   Batch 1586/1639 | Batch Recon Mean = 443.3852
#   Batch 1587/1639 | Batch Recon Mean = 422.1786
#   Batch 1588/1639 | Batch Recon Mean = 454.3020
#   Batch 1589/1639 | Batch Recon Mean = 766.4304
#   Batch 1590/1639 | Batch Recon Mean = 349.6066
#   Batch 1591/1639 | Batch Recon Mean = 469.5693
#   Batch 1592/1639 | Batch Recon Mean = 389.8577
#   Batch 1593/1639 | Batch Recon Mean = 428.0165
#   Batch 1594/1639 | Batch Recon Mean = 424.4517
#   Batch 1595/1639 | Batch Recon Mean = 417.5130
#   Batch 1596/1639 | Batch Recon Mean = 1236.7681
#   Batch 1597/1639 | Batch Recon Mean = 334.7800
#   Batch 1598/1639 | Batch Recon Mean = 8563.9746
#   Batch 1599/1639 | Batch Recon Mean = 353.5294
#   Batch 1600/1639 | Batch Recon Mean = 301.5746
#   Batch 1601/1639 | Batch Recon Mean = 453.0856
#   Batch 1602/1639 | Batch Recon Mean = 494.1447
#   Batch 1603/1639 | Batch Recon Mean = 328.6473
#   Batch 1604/1639 | Batch Recon Mean = 350.9478
#   Batch 1605/1639 | Batch Recon Mean = 388.8098
#   Batch 1606/1639 | Batch Recon Mean = 4207.5166
#   Batch 1607/1639 | Batch Recon Mean = 422.2535
#   Batch 1608/1639 | Batch Recon Mean = 463.9835
#   Batch 1609/1639 | Batch Recon Mean = 390.7794
#   Batch 1610/1639 | Batch Recon Mean = 331.2733
#   Batch 1611/1639 | Batch Recon Mean = 387.4545
#   Batch 1612/1639 | Batch Recon Mean = 4875.7607
#   Batch 1613/1639 | Batch Recon Mean = 774.1027
#   Batch 1614/1639 | Batch Recon Mean = 516.2379
#   Batch 1615/1639 | Batch Recon Mean = 13947.6992
#   Batch 1616/1639 | Batch Recon Mean = 449.1565
#   Batch 1617/1639 | Batch Recon Mean = 672.0352
#   Batch 1618/1639 | Batch Recon Mean = 506.4508
#   Batch 1619/1639 | Batch Recon Mean = 426.0832
#   Batch 1620/1639 | Batch Recon Mean = 330.3784
#   Batch 1621/1639 | Batch Recon Mean = 630.5266
#   Batch 1622/1639 | Batch Recon Mean = 714.6416
#   Batch 1623/1639 | Batch Recon Mean = 499.4681
#   Batch 1624/1639 | Batch Recon Mean = 379.6666
#   Batch 1625/1639 | Batch Recon Mean = 425.6735
#   Batch 1626/1639 | Batch Recon Mean = 359.6671
#   Batch 1627/1639 | Batch Recon Mean = 474.5169
#   Batch 1628/1639 | Batch Recon Mean = 475.3423
#   Batch 1629/1639 | Batch Recon Mean = 418.2922
#   Batch 1630/1639 | Batch Recon Mean = 579.9037
#   Batch 1631/1639 | Batch Recon Mean = 397.5234
#   Batch 1632/1639 | Batch Recon Mean = 461.4076
#   Batch 1633/1639 | Batch Recon Mean = 393.7095
#   Batch 1634/1639 | Batch Recon Mean = 493.2673
#   Batch 1635/1639 | Batch Recon Mean = 383.1965
#   Batch 1636/1639 | Batch Recon Mean = 1257.7720
#   Batch 1637/1639 | Batch Recon Mean = 450.2286
#   Batch 1638/1639 | Batch Recon Mean = 310.4395
#   Batch 1639/1639 | Batch Recon Mean = 207.3998
# Total samples recorded: 838668

# %%
#cross check per epoch
